# %%
import os
import csv
import random
from glob import glob
from typing import Dict

import numpy as np
from PIL import Image
import cv2

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader


# ============================================================
# PATH CONFIG — EDIT THESE FOR YOUR LOCAL MACHINE
# ============================================================

IMG_TRAIN = r"G:\historical document analysis\Latin2\images\train"
IMG_VAL = r"G:\historical document analysis\Latin2\images\val"
IMG_TEST = r"G:\historical document analysis\Latin2\images\test"

TL_MSK_TRAIN = r"G:\historical document analysis\Latin2\masks\train"
TL_MSK_VAL = r"G:\historical document analysis\Latin2\masks\val"
TL_MSK_TEST = r"G:\historical document analysis\Latin2\masks\test"

PRIOR_DIR_TRAIN = r"G:\historical document analysis\Latin2\priors\train"
PRIOR_DIR_VAL = r"G:\historical document analysis\Latin2\priors\val"
PRIOR_DIR_TEST = r"G:\historical document analysis\Latin2\priors\test"

STAGE1_CKPT = r"G:\Best UDIDS\best_maskprob_gauss.pt"

OUT_DIR = r"alpha_sensitivity_output"


# ============================================================
# TRAINING CONFIG
# ============================================================

EPOCHS = 250  # Stage 2 training epochs, consistent with the manuscript
BATCH_SIZE = 1
BASE = 48
LR_INIT = 1e-4
WEIGHT_DECAY = 0.0
GRAD_CLIP = 1.0

MAX_SIDE = 2048
PATCH = 512
TRAIN_PATCHES_PER_IMAGE = 8
POS_PATCH_PROB = 0.6
VAL_STRIDE = PATCH // 2

NUM_WORKERS = 0
PIN_MEMORY = torch.cuda.is_available()

CASCADE_USE_PRIOR_AS_INPUT = True

SEED = 42
ALLOWED = {".png", ".jpg", ".jpeg", ".tif", ".tiff", ".bmp"}


# ============================================================
# SENSITIVITY SETTINGS — ALPHA INTERVAL TEST
# ============================================================

FIXED_BETA = 1.5

RUNS = [
    {
        "name": "alpha_0.05_1.00_beta_1.5",
        "alpha_min": 0.05,
        "alpha_max": 1.00,
        "beta_gate": FIXED_BETA,
    },
    {
        "name": "alpha_0.05_1.00_beta_1.5",
        "alpha_min": 1,
        "alpha_max": 1.5,
        "beta_gate": FIXED_BETA,
    },
    {
        "name": "alpha_0.15_1.50_beta_1.5_default",
        "alpha_min": 1.5,
        "alpha_max": 2.5,
        "beta_gate": FIXED_BETA,
    },
    {
        "name": "alpha_0.05_5.00_beta_1.5_wide",
        "alpha_min": 2.5,
        "alpha_max": 3,
        "beta_gate": FIXED_BETA,
    },
    
    {
        "name": "alpha_0.05_5.00_beta_1.5_wide",
        "alpha_min": 3,
        "alpha_max": 3.5,
        "beta_gate": FIXED_BETA,
    },
    {
        "name": "alpha_0.05_5.00_beta_1.5_wide",
        "alpha_min": 3.5,
        "alpha_max": 4,
        "beta_gate": FIXED_BETA,
    },
]


# ============================================================
# REPRODUCIBILITY
# ============================================================

def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


set_seed(SEED)


# ============================================================
# I/O
# ============================================================

def load_rgb(path: str) -> np.ndarray:
    return np.array(Image.open(path).convert("RGB"))


def load_mask01(path: str) -> np.ndarray:
    return (np.array(Image.open(path).convert("L")) > 0).astype(np.uint8)


def resize_keep(img: np.ndarray, max_side: int = MAX_SIDE):
    h, w = img.shape[:2]
    s = max(h, w)

    if s <= max_side:
        return img, 1.0

    scale = max_side / float(s)
    new_w = int(round(w * scale))
    new_h = int(round(h * scale))

    if img.ndim == 3:
        interpolation = cv2.INTER_AREA
    else:
        interpolation = cv2.INTER_NEAREST

    out = cv2.resize(img, (new_w, new_h), interpolation=interpolation)
    return out, scale


# ============================================================
# DATASET
# ============================================================

class TextLineDataset(Dataset):
    def __init__(
        self,
        img_dir: str,
        mask_dir: str,
        prior_dir: str,
        stage1_model: nn.Module = None,
        device: torch.device = None,
        use_prior: bool = True,
    ):
        if not os.path.isdir(img_dir):
            raise FileNotFoundError(f"Image directory not found: {img_dir}")

        if not os.path.isdir(mask_dir):
            raise FileNotFoundError(f"Mask directory not found: {mask_dir}")

        img_paths = sorted(
            p for p in glob(os.path.join(img_dir, "*"))
            if os.path.splitext(p)[1].lower() in ALLOWED
        )

        mask_paths = sorted(
            p for p in glob(os.path.join(mask_dir, "*"))
            if os.path.splitext(p)[1].lower() in ALLOWED
        )

        mask_map = {
            os.path.splitext(os.path.basename(p))[0]: p
            for p in mask_paths
        }

        self.items = []
        for ip in img_paths:
            key = os.path.splitext(os.path.basename(ip))[0]
            if key in mask_map:
                self.items.append((ip, mask_map[key], key))
            else:
                print(f"[warning] no mask found for image: {ip}")

        if not self.items:
            raise RuntimeError(
                f"No image/mask pairs found between {img_dir} and {mask_dir}"
            )

        self.prior_dir = prior_dir
        self.stage1_model = stage1_model
        self.device = device
        self.use_prior = use_prior

        print(f"[dataset] {len(self.items)} pairs loaded from {img_dir}")

    def __len__(self):
        return len(self.items)

    def _resize_keep_aspect_img(self, img_np: np.ndarray, max_side: int = 768):
        h, w = img_np.shape
        s = max(h, w)

        if s <= max_side:
            return img_np, 1.0

        scale = max_side / float(s)
        new_w = int(round(w * scale))
        new_h = int(round(h * scale))

        img_res = np.array(
            Image.fromarray(img_np).resize((new_w, new_h), Image.BILINEAR)
        )
        return img_res, scale

    def _get_or_create_prior(self, key: str, img_path: str):
        npy_path = os.path.join(self.prior_dir, f"{key}.npy")
        png_path = os.path.join(self.prior_dir, f"{key}.png")

        if os.path.isfile(npy_path):
            prior = np.load(npy_path).astype(np.float32)
            if prior.max() > 1.0:
                prior = prior / 255.0
            return prior

        if os.path.isfile(png_path):
            prior = np.array(Image.open(png_path).convert("L")).astype(np.float32) / 255.0
            return prior

        if self.stage1_model is None:
            print(f"[warning] Missing prior for '{key}' and no Stage 1 model provided.")
            return None

        img_rgb = load_rgb(img_path)
        gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)
        gray_res, _ = self._resize_keep_aspect_img(gray, max_side=768)

        x_t = torch.from_numpy(gray_res.astype(np.float32) / 255.0)[None, None, ...]
        x_t = x_t.to(self.device)

        self.stage1_model.eval()
        with torch.no_grad():
            if self.device.type == "cuda":
                with torch.amp.autocast("cuda", enabled=True):
                    p = self.stage1_model(x_t)
            else:
                p = self.stage1_model(x_t)

        prior_res = p[0, 0].cpu().to(torch.float32).numpy()

        prior_full = cv2.resize(
            prior_res,
            (img_rgb.shape[1], img_rgb.shape[0]),
            interpolation=cv2.INTER_LINEAR,
        )
        prior_full = np.clip(prior_full, 0.0, 1.0).astype(np.float32)

        os.makedirs(self.prior_dir, exist_ok=True)
        np.save(npy_path, prior_full)

        return prior_full

    def _load_prior(self, key: str, img_path: str, h0: int, w0: int) -> np.ndarray:
        if not self.use_prior:
            return np.zeros((h0, w0), np.float32)

        prior_res = self._get_or_create_prior(key, img_path)

        if prior_res is None:
            return np.zeros((h0, w0), np.float32)

        if prior_res.shape != (h0, w0):
            prior = cv2.resize(prior_res, (w0, h0), interpolation=cv2.INTER_LINEAR)
        else:
            prior = prior_res

        return np.clip(prior, 0.0, 1.0).astype(np.float32)

    def __getitem__(self, idx: int) -> Dict[str, torch.Tensor]:
        img_path, mask_path, key = self.items[idx]

        img0 = load_rgb(img_path)
        mask0 = load_mask01(mask_path)

        h0, w0 = mask0.shape
        prior0 = self._load_prior(key, img_path, h0, w0)

        img, _ = resize_keep(img0, MAX_SIDE)
        h, w = img.shape[:2]

        mask = cv2.resize(mask0, (w, h), interpolation=cv2.INTER_NEAREST).astype(np.float32)
        prior = cv2.resize(prior0, (w, h), interpolation=cv2.INTER_LINEAR).astype(np.float32)
        prior = np.clip(prior, 0.0, 1.0)

        rgb = (img.astype(np.float32) / 255.0).transpose(2, 0, 1)

        if self.use_prior:
            x = np.concatenate([rgb, prior[None, ...]], axis=0)
        else:
            x = rgb

        return {
            "x": torch.from_numpy(x).float(),
            "y": torch.from_numpy(mask[None, ...]).float(),
            "prior": torch.from_numpy(prior[None, ...]).float(),
            "rgb": torch.from_numpy(rgb).float(),
            "name": os.path.basename(img_path),
        }


# ============================================================
# STAGE 1 MODEL — PRIOR REGRESSOR
# ============================================================

def _gn_groups(channels: int) -> int:
    for g in (32, 16, 8, 4, 2, 1):
        if channels % g == 0:
            return g
    return 1


class DoubleConv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        g = _gn_groups(out_ch)

        self.net = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1, bias=False),
            nn.GroupNorm(g, out_ch),
            nn.ReLU(inplace=True),

            nn.Conv2d(out_ch, out_ch, 3, padding=1, bias=False),
            nn.GroupNorm(g, out_ch),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.net(x)


class DownOld(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.pool = nn.MaxPool2d(2, 2)
        self.conv = DoubleConv(in_ch, out_ch)

    def forward(self, x):
        return self.conv(self.pool(x))


class UpOld(nn.Module):
    def __init__(self, in_ch, skip_ch, out_ch):
        super().__init__()
        self.reduce = nn.Conv2d(in_ch, out_ch, 1, bias=False)
        self.conv = DoubleConv(out_ch + skip_ch, out_ch)

    def forward(self, x, skip):
        x = F.interpolate(
            x,
            size=skip.shape[-2:],
            mode="bilinear",
            align_corners=False,
        )
        x = self.reduce(x)
        x = torch.cat([x, skip], dim=1)
        return self.conv(x)


class UNetMaskProb(nn.Module):
    def __init__(self, in_ch=1, base=32):
        super().__init__()

        self.e1 = DoubleConv(in_ch, base)
        self.e2 = DownOld(base, base * 2)
        self.e3 = DownOld(base * 2, base * 4)
        self.e4 = DownOld(base * 4, base * 8)

        self.bott = DoubleConv(base * 8, base * 16)

        self.u4 = UpOld(base * 16, base * 8, base * 8)
        self.u3 = UpOld(base * 8, base * 4, base * 4)
        self.u2 = UpOld(base * 4, base * 2, base * 2)
        self.u1 = UpOld(base * 2, base, base)

        self.head = nn.Conv2d(base, 1, 1)

    def forward(self, x):
        s1 = self.e1(x)
        s2 = self.e2(s1)
        s3 = self.e3(s2)
        s4 = self.e4(s3)

        z = self.bott(s4)

        z = self.u4(z, s4)
        z = self.u3(z, s3)
        z = self.u2(z, s2)
        z = self.u1(z, s1)

        return torch.sigmoid(self.head(z))


# ============================================================
# STAGE 2 MODEL
# ============================================================

def group_norm_groups(channels: int) -> int:
    for g in (32, 16, 8, 4, 2, 1):
        if channels % g == 0:
            return g
    return 1


class Block(nn.Module):
    def __init__(self, c_in: int, c_out: int, dropout: float = 0.0):
        super().__init__()
        g = group_norm_groups(c_out)

        self.net = nn.Sequential(
            nn.Conv2d(c_in, c_out, 3, padding=1, bias=False),
            nn.GroupNorm(g, c_out),
            nn.ReLU(inplace=True),

            nn.Conv2d(c_out, c_out, 3, padding=1, bias=False),
            nn.GroupNorm(g, c_out),
            nn.ReLU(inplace=True),

            nn.Dropout2d(dropout) if dropout > 0 else nn.Identity(),
        )

    def forward(self, x):
        return self.net(x)


class Down(nn.Module):
    def __init__(self, c_in: int, c_out: int, dropout: float = 0.0):
        super().__init__()
        self.pool = nn.MaxPool2d(2, 2)
        self.block = Block(c_in, c_out, dropout)

    def forward(self, x):
        return self.block(self.pool(x))


class Up(nn.Module):
    def __init__(self, c_in: int, c_skip: int, c_out: int, dropout: float = 0.0):
        super().__init__()
        self.red = nn.Conv2d(c_in, c_out, 1, bias=False)
        self.block = Block(c_out + c_skip, c_out, dropout)

    def forward(self, x, skip):
        x = F.interpolate(
            x,
            size=skip.shape[-2:],
            mode="bilinear",
            align_corners=False,
        )
        x = self.red(x)
        x = torch.cat([x, skip], dim=1)
        return self.block(x)


def safe_logit(p: torch.Tensor, eps: float = 1e-6) -> torch.Tensor:
    p = p.clamp(eps, 1.0 - eps)
    return torch.log(p) - torch.log(1.0 - p)


class UNetTextLines(nn.Module):
    def __init__(
        self,
        in_ch: int = 4,
        base: int = 64,
        dropout: float = 0.1,
        alpha_min: float = 0.15,
        alpha_max: float = 1.50,
        beta_gate: float = 1.0,
        res_scale: float = 2.0,
    ):
        super().__init__()

        self.in_ch = in_ch
        self.alpha_min = float(alpha_min)
        self.alpha_max = float(alpha_max)
        self.beta_gate = float(beta_gate)
        self.res_scale = float(res_scale)

        self.e1 = Block(in_ch, base, dropout)
        self.e2 = Down(base, base * 2, dropout)
        self.e3 = Down(base * 2, base * 4, dropout)
        self.e4 = Down(base * 4, base * 8, dropout)

        self.bott = Block(base * 8, base * 16, dropout)

        self.u4 = Up(base * 16, base * 8, base * 8, dropout)
        self.u3 = Up(base * 8, base * 4, base * 4, dropout)
        self.u2 = Up(base * 4, base * 2, base * 2, dropout)
        self.u1 = Up(base * 2, base, base, 0.0)

        self.head_delta = nn.Conv2d(base, 2, 1)
        self.head_gate = nn.Conv2d(base, 1, 1)
        self.head_alpha = nn.Conv2d(base, 1, 1)

        nn.init.zeros_(self.head_delta.weight)
        nn.init.zeros_(self.head_delta.bias)

        nn.init.zeros_(self.head_gate.weight)
        nn.init.constant_(self.head_gate.bias, -2.0)

        nn.init.zeros_(self.head_alpha.weight)
        nn.init.constant_(self.head_alpha.bias, 0.0)

    def forward(self, x):
        s1 = self.e1(x)
        s2 = self.e2(s1)
        s3 = self.e3(s2)
        s4 = self.e4(s3)

        z = self.bott(s4)

        z = self.u4(z, s4)
        z = self.u3(z, s3)
        z = self.u2(z, s2)
        z = self.u1(z, s1)

        if self.in_ch >= 4:
            prior = x[:, 3:4].clamp(0.0, 1.0)

            l_fg = safe_logit(prior)
            l_bg = safe_logit(1.0 - prior)

            prior_logits = torch.cat([l_bg, l_fg], dim=1)
            prior_conf_mask = prior.pow(self.beta_gate)
        else:
            b, _, h, w = x.shape
            prior_logits = torch.zeros(
                b, 2, h, w, device=x.device, dtype=x.dtype
            )
            prior_conf_mask = torch.zeros(
                b, 1, h, w, device=x.device, dtype=x.dtype
            )

        delta = self.res_scale * torch.tanh(self.head_delta(z))
        delta = prior_conf_mask * delta

        gate = torch.sigmoid(self.head_gate(z))

        alpha_raw = torch.sigmoid(self.head_alpha(z))
        alpha_map = self.alpha_min + (self.alpha_max - self.alpha_min) * alpha_raw

        fused_logits = alpha_map * prior_logits + gate * delta

        return fused_logits, alpha_map


# ============================================================
# METRICS
# ============================================================

def evaluate_metrics_np(gt_u8: np.ndarray, pr_u8: np.ndarray, thresh: float = 0.75):
    ng, gt_lbl = cv2.connectedComponents(gt_u8)
    npred, pr_lbl = cv2.connectedComponents(pr_u8)

    inter = np.logical_and(gt_lbl > 0, pr_lbl > 0).sum()
    union = np.logical_or(gt_lbl > 0, pr_lbl > 0).sum()
    pixel_iou = inter / union if union > 0 else 0.0

    m = ng
    n = npred

    if m <= 1 or n <= 1:
        return pixel_iou, 0.0, 0.0, 0.0, 0.0

    table = np.bincount(
        gt_lbl.ravel() * n + pr_lbl.ravel(),
        minlength=m * n,
    ).reshape(m, n)

    area_gt = table.sum(axis=1)[:, None]
    area_pr = table.sum(axis=0)[None, :]

    iou = table / (area_gt + area_pr - table + 1e-8)

    rows, cols = np.where(
        (iou >= thresh)
        & (np.arange(m)[:, None] > 0)
        & (np.arange(n)[None, :] > 0)
    )

    matches = len(rows)

    dr = matches / max(1, (m - 1))
    ra = matches / max(1, (n - 1))
    fm = 2 * dr * ra / (dr + ra + 1e-8)

    sub = iou[1:, 1:]
    best_pr = sub.argmax(axis=1) + 1
    gt_i = np.arange(1, m)
    pr_i = best_pr

    ints = table[gt_i, pr_i]
    precs = ints / (area_pr[0, pr_i] + 1e-8)
    recs = ints / (area_gt[gt_i, 0] + 1e-8)

    cl = (precs >= thresh) & (recs >= thresh)
    ml = recs < thresh
    el = (precs < thresh) & (recs >= thresh)

    line_iu = cl.sum() / max(1, (cl.sum() + ml.sum() + el.sum()))

    return pixel_iou, line_iu, dr, ra, fm


def cosine_window_2d(h: int, w: int, eps: float = 1e-3) -> np.ndarray:
    wy = np.hanning(h) if h > 1 else np.ones(1)
    wx = np.hanning(w) if w > 1 else np.ones(1)
    win = np.outer(wy, wx).astype(np.float32)
    return np.clip(win, eps, 1.0)


def sample_random_patch(h: int, w: int, ph: int, pw: int, yc=None, xc=None):
    if yc is not None and xc is not None:
        y0 = max(0, min(h - ph, int(yc - ph // 2)))
        x0 = max(0, min(w - pw, int(xc - pw // 2)))
        return y0, x0

    y0 = 0 if h <= ph else random.randint(0, h - ph)
    x0 = 0 if w <= pw else random.randint(0, w - pw)
    return y0, x0


# ============================================================
# DATALOADER
# ============================================================

def make_loader(ds: Dataset, shuffle: bool):
    return DataLoader(
        ds,
        batch_size=BATCH_SIZE,
        shuffle=shuffle,
        num_workers=NUM_WORKERS,
        pin_memory=PIN_MEMORY,
    )


# ============================================================
# TRAIN ONE SENSITIVITY RUN
# ============================================================

def train_one_run(run_cfg: dict):
    run_name = run_cfg["name"]
    alpha_min = run_cfg["alpha_min"]
    alpha_max = run_cfg["alpha_max"]
    beta_gate = run_cfg["beta_gate"]

    set_seed(SEED)

    run_dir = os.path.join(OUT_DIR, run_name)
    preview_dir = os.path.join(run_dir, "preview")

    os.makedirs(run_dir, exist_ok=True)
    os.makedirs(preview_dir, exist_ok=True)

    ckpt_best = os.path.join(run_dir, "best_lineiu.pt")
    ckpt_last = os.path.join(run_dir, "last_lineiu.pt")
    log_csv = os.path.join(run_dir, "metrics_lineiu.csv")

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    print("\n" + "=" * 90)
    print(f"Run: {run_name}")
    print(f"Device: {device}")
    print(f"alpha_min={alpha_min}, alpha_max={alpha_max}, beta_gate={beta_gate}")
    print("=" * 90)

    if device.type == "cuda":
        torch.backends.cudnn.benchmark = True
        try:
            torch.set_float32_matmul_precision("high")
        except Exception:
            pass

    stage1_model = None
    if CASCADE_USE_PRIOR_AS_INPUT:
        stage1_model = UNetMaskProb(in_ch=1, base=32).to(device)
        state = torch.load(STAGE1_CKPT, map_location=device)

        if isinstance(state, dict) and "model" in state:
            stage1_model.load_state_dict(state["model"], strict=True)
        else:
            stage1_model.load_state_dict(state, strict=True)

        stage1_model.eval()
        print(f"Loaded Stage 1 model from {STAGE1_CKPT}")

    ds_train = TextLineDataset(
        IMG_TRAIN,
        TL_MSK_TRAIN,
        prior_dir=PRIOR_DIR_TRAIN,
        stage1_model=stage1_model,
        device=device,
        use_prior=CASCADE_USE_PRIOR_AS_INPUT,
    )

    ds_val = TextLineDataset(
        IMG_VAL,
        TL_MSK_VAL,
        prior_dir=PRIOR_DIR_VAL,
        stage1_model=stage1_model,
        device=device,
        use_prior=CASCADE_USE_PRIOR_AS_INPUT,
    )

    ds_test = TextLineDataset(
        IMG_TEST,
        TL_MSK_TEST,
        prior_dir=PRIOR_DIR_TEST,
        stage1_model=stage1_model,
        device=device,
        use_prior=CASCADE_USE_PRIOR_AS_INPUT,
    )

    train_loader = make_loader(ds_train, shuffle=True)
    val_loader = make_loader(ds_val, shuffle=False)
    test_loader = make_loader(ds_test, shuffle=False)

    in_ch = 4 if CASCADE_USE_PRIOR_AS_INPUT else 3

    model = UNetTextLines(
        in_ch=in_ch,
        base=BASE,
        dropout=0.1,
        alpha_min=alpha_min,
        alpha_max=alpha_max,
        beta_gate=beta_gate,
    ).to(device)

    if device.type == "cuda":
        model = model.to(memory_format=torch.channels_last)

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=LR_INIT,
        weight_decay=WEIGHT_DECAY,
    )

    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer,
        T_max=EPOCHS,
        eta_min=LR_INIT * 0.1,
    )

    use_amp = device.type == "cuda"
    scaler = torch.amp.GradScaler("cuda", enabled=use_amp)
    ce_loss = nn.CrossEntropyLoss()

    best_lineiu = -1.0
    best_row = None

    for epoch in range(1, EPOCHS + 1):
        model.train()
        train_loss = 0.0

        for batch in train_loader:
            x_full = batch["x"].to(device, non_blocking=True).float()
            y_full = batch["y"].to(device, non_blocking=True).float()

            if device.type == "cuda":
                x_full = x_full.to(memory_format=torch.channels_last)
                y_full = y_full.to(memory_format=torch.channels_last)

            _, _, h, w = x_full.shape

            for _ in range(TRAIN_PATCHES_PER_IMAGE):
                yc = None
                xc = None

                if random.random() < POS_PATCH_PROB:
                    pos = torch.nonzero(y_full[0, 0] > 0.5, as_tuple=False)
                    if pos.numel() > 0:
                        selected = pos[random.randrange(pos.shape[0])].tolist()
                        yc, xc = selected[0], selected[1]

                y0, x0 = sample_random_patch(h, w, PATCH, PATCH, yc, xc)
                y1 = min(h, y0 + PATCH)
                x1 = min(w, x0 + PATCH)

                x = x_full[:, :, y0:y1, x0:x1]
                y = y_full[:, :, y0:y1, x0:x1]

                target = (y > 0.5).long().squeeze(1)

                optimizer.zero_grad(set_to_none=True)

                if use_amp:
                    with torch.amp.autocast("cuda", enabled=True):
                        fused_logits, _ = model(x)
                        loss = ce_loss(fused_logits, target)
                else:
                    fused_logits, _ = model(x)
                    loss = ce_loss(fused_logits, target)

                scaler.scale(loss).backward()

                if GRAD_CLIP is not None and GRAD_CLIP > 0:
                    scaler.unscale_(optimizer)
                    nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP)

                scaler.step(optimizer)
                scaler.update()

                train_loss += float(loss.item()) * x.size(0)

        train_loss /= max(1, len(ds_train) * TRAIN_PATCHES_PER_IMAGE)

        model.eval()

        val_ce = 0.0
        val_pixel_iou_list = []
        val_lineiu_list = []
        val_dr_list = []
        val_ra_list = []
        val_fm_list = []
        alpha_means = []

        with torch.no_grad():
            for i, batch in enumerate(val_loader):
                x_full = batch["x"][0].to(device).float()
                y_full = batch["y"][0].to(device).float()

                c, h, w = x_full.shape

                acc = torch.zeros((1, h, w), device=device, dtype=torch.float32)
                wgt = torch.zeros((1, h, w), device=device, dtype=torch.float32)

                acc_alpha = torch.zeros((1, h, w), device=device, dtype=torch.float32)
                wgt_alpha = torch.zeros((1, h, w), device=device, dtype=torch.float32)

                ys = list(range(0, max(1, h - PATCH + 1), VAL_STRIDE))
                xs = list(range(0, max(1, w - PATCH + 1), VAL_STRIDE))

                edge_y = max(0, h - PATCH)
                edge_x = max(0, w - PATCH)

                if ys[-1] != edge_y:
                    ys.append(edge_y)
                if xs[-1] != edge_x:
                    xs.append(edge_x)

                win_cache = {}

                for y0 in ys:
                    for x0 in xs:
                        y1 = min(h, y0 + PATCH)
                        x1 = min(w, x0 + PATCH)

                        tile = x_full[:, y0:y1, x0:x1].unsqueeze(0).to(device)

                        fused_logits, alpha_map = model(tile)
                        prob = torch.softmax(fused_logits, dim=1)[:, 1:2]

                        th = y1 - y0
                        tw = x1 - x0

                        key = (th, tw)
                        if key not in win_cache:
                            win_cache[key] = torch.from_numpy(
                                cosine_window_2d(th, tw)
                            ).to(device=device, dtype=torch.float32)

                        win = win_cache[key]

                        acc[:, y0:y1, x0:x1] += prob.squeeze(0) * win
                        wgt[:, y0:y1, x0:x1] += win

                        acc_alpha[:, y0:y1, x0:x1] += alpha_map.squeeze(0) * win
                        wgt_alpha[:, y0:y1, x0:x1] += win

                prob_full = torch.where(wgt > 0, acc / wgt, acc).clamp(0.0, 1.0)
                alpha_full = torch.where(
                    wgt_alpha > 0,
                    acc_alpha / wgt_alpha,
                    acc_alpha,
                )
                alpha_means.append(float(alpha_full.mean().cpu()))

                p = prob_full.clamp(1e-6, 1.0 - 1e-6)
                l_fg = torch.log(p) - torch.log(1.0 - p)
                l_bg = -l_fg
                logits_full = torch.cat([l_bg, l_fg], dim=0).unsqueeze(0)

                target_full = (y_full > 0.5).long().squeeze(0).unsqueeze(0)
                loss_val = ce_loss(logits_full, target_full)
                val_ce += float(loss_val.item())

                pred = (prob_full >= 0.5).float()
                gt = (y_full > 0.5).float()

                gt_u8 = (gt[0].cpu().numpy().astype(np.uint8)) * 255
                pr_u8 = (pred[0].cpu().numpy().astype(np.uint8)) * 255

                pixel_iou, line_iu, dr, ra, fm = evaluate_metrics_np(
                    gt_u8,
                    pr_u8,
                    thresh=0.75,
                )

                val_pixel_iou_list.append(pixel_iou)
                val_lineiu_list.append(line_iu)
                val_dr_list.append(dr)
                val_ra_list.append(ra)
                val_fm_list.append(fm)

                if i == 0 and (epoch == 1 or epoch % 25 == 0):
                    rgb = (batch["rgb"][0].numpy().transpose(1, 2, 0) * 255).astype(np.uint8)
                    rgb_bgr = cv2.cvtColor(rgb, cv2.COLOR_RGB2BGR)

                    pred_u8 = (prob_full[0].cpu().numpy() * 255).astype(np.uint8)
                    gt_u8_vis = (gt[0].cpu().numpy() * 255).astype(np.uint8)

                    pred_color = cv2.applyColorMap(pred_u8, cv2.COLORMAP_JET)
                    gt_color = cv2.applyColorMap(gt_u8_vis, cv2.COLORMAP_JET)

                    ov_pred = cv2.addWeighted(rgb_bgr, 0.5, pred_color, 0.6, 0)
                    ov_gt = cv2.addWeighted(rgb_bgr, 0.5, gt_color, 0.6, 0)

                    cv2.imwrite(os.path.join(preview_dir, f"ep{epoch:03d}_img.png"), rgb_bgr)
                    cv2.imwrite(os.path.join(preview_dir, f"ep{epoch:03d}_pred_prob.png"), pred_u8)
                    cv2.imwrite(os.path.join(preview_dir, f"ep{epoch:03d}_gt.png"), gt_u8_vis)
                    cv2.imwrite(os.path.join(preview_dir, f"ep{epoch:03d}_ov_pred.png"), ov_pred)
                    cv2.imwrite(os.path.join(preview_dir, f"ep{epoch:03d}_ov_gt.png"), ov_gt)

                    prior_u8 = (batch["prior"][0, 0].numpy().clip(0, 1) * 255).astype(np.uint8)
                    cv2.imwrite(os.path.join(preview_dir, f"ep{epoch:03d}_prior.png"), prior_u8)

        val_ce /= max(1, len(ds_val))
        val_pixel_iou = float(np.mean(val_pixel_iou_list)) if val_pixel_iou_list else 0.0
        val_lineiu = float(np.mean(val_lineiu_list)) if val_lineiu_list else 0.0
        val_dr = float(np.mean(val_dr_list)) if val_dr_list else 0.0
        val_ra = float(np.mean(val_ra_list)) if val_ra_list else 0.0
        val_fm = float(np.mean(val_fm_list)) if val_fm_list else 0.0
        alpha_mean = float(np.mean(alpha_means)) if alpha_means else 0.0

        scheduler.step()

        print(
            f"[{run_name}] Epoch {epoch:03d} | "
            f"trainCE={train_loss:.5f} | valCE={val_ce:.5f} | "
            f"PixelIoU={val_pixel_iou:.4f} | LineIU={val_lineiu:.4f} | "
            f"DR={val_dr:.4f} | RA={val_ra:.4f} | FM={val_fm:.4f} | "
            f"alpha_mean={alpha_mean:.3f}"
        )

        row = {
            "epoch": epoch,
            "lr": optimizer.param_groups[0]["lr"],
            "val_pixel_iou": val_pixel_iou,
            "val_lineiu": val_lineiu,
            "val_dr": val_dr,
            "val_ra": val_ra,
            "val_fm": val_fm,
            "alpha_mean": alpha_mean,
            "alpha_min": alpha_min,
            "alpha_max": alpha_max,
            "beta_gate": beta_gate,
        }

        write_header = not os.path.isfile(log_csv)
        with open(log_csv, "a", newline="") as f:
            writer = csv.DictWriter(f, fieldnames=list(row.keys()))
            if write_header:
                writer.writeheader()
            writer.writerow(row)

        state = {
            "model": model.state_dict(),
            "epoch": epoch,
            "val_pixel_iou": val_pixel_iou,
            "val_lineiu": val_lineiu,
            "val_dr": val_dr,
            "val_ra": val_ra,
            "val_fm": val_fm,
            "arch": "unet_textlines_alpha_sensitivity",
            "base": BASE,
            "in_ch": in_ch,
            "patch": PATCH,
            "val_stride": VAL_STRIDE,
            "alpha_min": alpha_min,
            "alpha_max": alpha_max,
            "beta_gate": beta_gate,
        }

        torch.save(state, ckpt_last)

        if val_lineiu > best_lineiu:
            best_lineiu = val_lineiu
            best_row = row.copy()
            torch.save(state, ckpt_best)
            print(f"Saved best checkpoint: {ckpt_best} | LineIU={val_lineiu:.4f}")

    print(f"\n--- Evaluating best model on TEST split for {run_name} ---")

    state = torch.load(ckpt_best, map_location=device)
    model.load_state_dict(state["model"], strict=True)
    model.eval()

    test_pixel_iou_list = []
    test_lineiu_list = []
    test_dr_list = []
    test_ra_list = []
    test_fm_list = []

    with torch.no_grad():
        for batch in test_loader:
            x_full = batch["x"][0].to(device).float()
            y_full = batch["y"][0].to(device).float()

            c, h, w = x_full.shape

            acc = torch.zeros((1, h, w), device=device, dtype=torch.float32)
            wgt = torch.zeros((1, h, w), device=device, dtype=torch.float32)

            ys = list(range(0, max(1, h - PATCH + 1), VAL_STRIDE))
            xs = list(range(0, max(1, w - PATCH + 1), VAL_STRIDE))

            edge_y = max(0, h - PATCH)
            edge_x = max(0, w - PATCH)

            if ys[-1] != edge_y:
                ys.append(edge_y)
            if xs[-1] != edge_x:
                xs.append(edge_x)

            win_cache = {}

            for y0 in ys:
                for x0 in xs:
                    y1 = min(h, y0 + PATCH)
                    x1 = min(w, x0 + PATCH)

                    tile = x_full[:, y0:y1, x0:x1].unsqueeze(0).to(device)
                    fused_logits, _ = model(tile)
                    prob = torch.softmax(fused_logits, dim=1)[:, 1:2]

                    th = y1 - y0
                    tw = x1 - x0

                    key = (th, tw)
                    if key not in win_cache:
                        win_cache[key] = torch.from_numpy(
                            cosine_window_2d(th, tw)
                        ).to(device=device, dtype=torch.float32)

                    win = win_cache[key]

                    acc[:, y0:y1, x0:x1] += prob.squeeze(0) * win
                    wgt[:, y0:y1, x0:x1] += win

            prob_full = torch.where(wgt > 0, acc / wgt, acc).clamp(0.0, 1.0)

            pred = (prob_full >= 0.5).float()
            gt = (y_full > 0.5).float()

            gt_u8 = (gt[0].cpu().numpy().astype(np.uint8)) * 255
            pr_u8 = (pred[0].cpu().numpy().astype(np.uint8)) * 255

            pixel_iou, line_iu, dr, ra, fm = evaluate_metrics_np(
                gt_u8,
                pr_u8,
                thresh=0.75,
            )

            test_pixel_iou_list.append(pixel_iou)
            test_lineiu_list.append(line_iu)
            test_dr_list.append(dr)
            test_ra_list.append(ra)
            test_fm_list.append(fm)

    test_pixel_iou = float(np.mean(test_pixel_iou_list)) if test_pixel_iou_list else 0.0
    test_lineiu = float(np.mean(test_lineiu_list)) if test_lineiu_list else 0.0
    test_dr = float(np.mean(test_dr_list)) if test_dr_list else 0.0
    test_ra = float(np.mean(test_ra_list)) if test_ra_list else 0.0
    test_fm = float(np.mean(test_fm_list)) if test_fm_list else 0.0

    print(
        f"TEST RESULTS | "
        f"PixelIoU={test_pixel_iou:.4f} | LineIU={test_lineiu:.4f} | "
        f"DR={test_dr:.4f} | RA={test_ra:.4f} | FM={test_fm:.4f}"
    )

    if best_row is not None:
        best_row["test_pixel_iou"] = test_pixel_iou
        best_row["test_lineiu"] = test_lineiu
        best_row["test_dr"] = test_dr
        best_row["test_ra"] = test_ra
        best_row["test_fm"] = test_fm

    return best_row


# ============================================================
# RUN ALL ALPHA SENSITIVITY TESTS
# ============================================================

def run_all_sensitivity_tests():
    os.makedirs(OUT_DIR, exist_ok=True)

    summary_path = os.path.join(OUT_DIR, "alpha_sensitivity_summary.csv")
    summary_rows = []

    for cfg in RUNS:
        best_row = train_one_run(cfg)

        if best_row is None:
            best_row = {
                "epoch": None,
                "val_pixel_iou": None,
                "val_lineiu": None,
                "val_dr": None,
                "val_ra": None,
                "val_fm": None,
                "alpha_mean": None,
                "test_pixel_iou": None,
                "test_lineiu": None,
                "test_dr": None,
                "test_ra": None,
                "test_fm": None,
            }

        summary_rows.append({
            "run_name": cfg["name"],
            "alpha_min": cfg["alpha_min"],
            "alpha_max": cfg["alpha_max"],
            "beta_gate": cfg["beta_gate"],
            "best_epoch": best_row["epoch"],
            "best_val_pixel_iou": best_row["val_pixel_iou"],
            "best_val_lineiu": best_row["val_lineiu"],
            "best_val_dr": best_row.get("val_dr"),
            "best_val_ra": best_row.get("val_ra"),
            "best_val_fm": best_row["val_fm"],
            "best_alpha_mean": best_row.get("alpha_mean"),
            "test_pixel_iou": best_row.get("test_pixel_iou"),
            "test_lineiu": best_row.get("test_lineiu"),
            "test_dr": best_row.get("test_dr"),
            "test_ra": best_row.get("test_ra"),
            "test_fm": best_row.get("test_fm"),
        })

    with open(summary_path, "w", newline="") as f:
        fieldnames = list(summary_rows[0].keys())
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(summary_rows)

    print("\nAlpha sensitivity summary saved to:")
    print(summary_path)

    print("\nSummary:")
    for row in summary_rows:
        print(row)


if __name__ == "__main__":
    run_all_sensitivity_tests()
# Out:
# ==========================================================================================
# Run: alpha_0.05_1.00_beta_1.5
# Device: cuda
# alpha_min=0.05, alpha_max=1.0, beta_gate=1.5
# ==========================================================================================
# Loaded Stage 1 model from G:\Best UDIDS\best_maskprob_gauss.pt
# [dataset] 3 pairs loaded from G:\historical document analysis\Latin2\images\train
# [dataset] 10 pairs loaded from G:\historical document analysis\Latin2\images\val
# [dataset] 15 pairs loaded from G:\historical document analysis\Latin2\images\test
# [alpha_0.05_1.00_beta_1.5] Epoch 001 | trainCE=0.32498 | valCE=0.22005 | PixelIoU=0.5497 | LineIU=0.1515 | DR=0.0017 | RA=0.0021 | FM=0.0019 | alpha_mean=0.532
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.1515
# [alpha_0.05_1.00_beta_1.5] Epoch 002 | trainCE=0.29068 | valCE=0.21085 | PixelIoU=0.5516 | LineIU=0.1660 | DR=0.0017 | RA=0.0021 | FM=0.0019 | alpha_mean=0.539
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.1660
# [alpha_0.05_1.00_beta_1.5] Epoch 003 | trainCE=0.30369 | valCE=0.19388 | PixelIoU=0.5564 | LineIU=0.1994 | DR=0.0017 | RA=0.0021 | FM=0.0019 | alpha_mean=0.536
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.1994
# [alpha_0.05_1.00_beta_1.5] Epoch 004 | trainCE=0.31106 | valCE=0.17822 | PixelIoU=0.5814 | LineIU=0.4166 | DR=0.0128 | RA=0.0124 | FM=0.0126 | alpha_mean=0.541
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.4166
# [alpha_0.05_1.00_beta_1.5] Epoch 005 | trainCE=0.28636 | valCE=0.16255 | PixelIoU=0.6037 | LineIU=0.6092 | DR=0.0466 | RA=0.0382 | FM=0.0419 | alpha_mean=0.538
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.6092
# [alpha_0.05_1.00_beta_1.5] Epoch 006 | trainCE=0.25543 | valCE=0.15785 | PixelIoU=0.6315 | LineIU=0.7443 | DR=0.1024 | RA=0.0909 | FM=0.0960 | alpha_mean=0.547
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7443
# [alpha_0.05_1.00_beta_1.5] Epoch 007 | trainCE=0.27631 | valCE=0.14396 | PixelIoU=0.6524 | LineIU=0.7635 | DR=0.1622 | RA=0.1342 | FM=0.1461 | alpha_mean=0.547
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7635
# [alpha_0.05_1.00_beta_1.5] Epoch 008 | trainCE=0.26953 | valCE=0.13665 | PixelIoU=0.6492 | LineIU=0.7534 | DR=0.1396 | RA=0.1159 | FM=0.1260 | alpha_mean=0.551
# [alpha_0.05_1.00_beta_1.5] Epoch 009 | trainCE=0.25197 | valCE=0.13252 | PixelIoU=0.6572 | LineIU=0.7758 | DR=0.1569 | RA=0.1382 | FM=0.1461 | alpha_mean=0.563
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7758
# [alpha_0.05_1.00_beta_1.5] Epoch 010 | trainCE=0.23725 | valCE=0.11736 | PixelIoU=0.6868 | LineIU=0.7791 | DR=0.3386 | RA=0.2332 | FM=0.2712 | alpha_mean=0.566
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7791
# [alpha_0.05_1.00_beta_1.5] Epoch 011 | trainCE=0.24606 | valCE=0.11309 | PixelIoU=0.6985 | LineIU=0.7801 | DR=0.3882 | RA=0.2666 | FM=0.3116 | alpha_mean=0.579
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7801
# [alpha_0.05_1.00_beta_1.5] Epoch 012 | trainCE=0.20478 | valCE=0.11248 | PixelIoU=0.6975 | LineIU=0.7922 | DR=0.4106 | RA=0.3047 | FM=0.3424 | alpha_mean=0.581
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7922
# [alpha_0.05_1.00_beta_1.5] Epoch 013 | trainCE=0.23678 | valCE=0.10457 | PixelIoU=0.7078 | LineIU=0.7755 | DR=0.4670 | RA=0.2935 | FM=0.3548 | alpha_mean=0.584
# [alpha_0.05_1.00_beta_1.5] Epoch 014 | trainCE=0.20577 | valCE=0.10097 | PixelIoU=0.7060 | LineIU=0.7909 | DR=0.4264 | RA=0.2717 | FM=0.3265 | alpha_mean=0.586
# [alpha_0.05_1.00_beta_1.5] Epoch 015 | trainCE=0.23062 | valCE=0.09896 | PixelIoU=0.7110 | LineIU=0.7729 | DR=0.4529 | RA=0.2691 | FM=0.3314 | alpha_mean=0.599
# [alpha_0.05_1.00_beta_1.5] Epoch 016 | trainCE=0.19922 | valCE=0.09767 | PixelIoU=0.7138 | LineIU=0.7747 | DR=0.4918 | RA=0.3003 | FM=0.3654 | alpha_mean=0.608
# [alpha_0.05_1.00_beta_1.5] Epoch 017 | trainCE=0.19793 | valCE=0.10063 | PixelIoU=0.7067 | LineIU=0.7951 | DR=0.4675 | RA=0.3485 | FM=0.3921 | alpha_mean=0.619
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7951
# [alpha_0.05_1.00_beta_1.5] Epoch 018 | trainCE=0.20429 | valCE=0.09916 | PixelIoU=0.7076 | LineIU=0.8099 | DR=0.4712 | RA=0.3311 | FM=0.3823 | alpha_mean=0.636
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.8099
# [alpha_0.05_1.00_beta_1.5] Epoch 019 | trainCE=0.19633 | valCE=0.09717 | PixelIoU=0.7092 | LineIU=0.8115 | DR=0.4764 | RA=0.3133 | FM=0.3715 | alpha_mean=0.648
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.8115
# [alpha_0.05_1.00_beta_1.5] Epoch 020 | trainCE=0.19442 | valCE=0.09101 | PixelIoU=0.7174 | LineIU=0.7996 | DR=0.5378 | RA=0.3337 | FM=0.4032 | alpha_mean=0.632
# [alpha_0.05_1.00_beta_1.5] Epoch 021 | trainCE=0.20516 | valCE=0.09117 | PixelIoU=0.7121 | LineIU=0.8011 | DR=0.4821 | RA=0.2982 | FM=0.3622 | alpha_mean=0.640
# [alpha_0.05_1.00_beta_1.5] Epoch 022 | trainCE=0.18660 | valCE=0.08989 | PixelIoU=0.7166 | LineIU=0.7966 | DR=0.5092 | RA=0.3119 | FM=0.3793 | alpha_mean=0.660
# [alpha_0.05_1.00_beta_1.5] Epoch 023 | trainCE=0.17023 | valCE=0.09375 | PixelIoU=0.7151 | LineIU=0.7871 | DR=0.5381 | RA=0.3689 | FM=0.4283 | alpha_mean=0.671
# [alpha_0.05_1.00_beta_1.5] Epoch 024 | trainCE=0.20265 | valCE=0.09168 | PixelIoU=0.7164 | LineIU=0.7884 | DR=0.5610 | RA=0.3703 | FM=0.4364 | alpha_mean=0.669
# [alpha_0.05_1.00_beta_1.5] Epoch 025 | trainCE=0.17792 | valCE=0.09200 | PixelIoU=0.7159 | LineIU=0.8103 | DR=0.5112 | RA=0.3338 | FM=0.3961 | alpha_mean=0.689
# [alpha_0.05_1.00_beta_1.5] Epoch 026 | trainCE=0.17824 | valCE=0.08659 | PixelIoU=0.7208 | LineIU=0.7926 | DR=0.5431 | RA=0.3248 | FM=0.3974 | alpha_mean=0.668
# [alpha_0.05_1.00_beta_1.5] Epoch 027 | trainCE=0.18356 | valCE=0.08962 | PixelIoU=0.7202 | LineIU=0.7811 | DR=0.5520 | RA=0.3666 | FM=0.4312 | alpha_mean=0.689
# [alpha_0.05_1.00_beta_1.5] Epoch 028 | trainCE=0.18543 | valCE=0.08817 | PixelIoU=0.7228 | LineIU=0.8071 | DR=0.5684 | RA=0.3654 | FM=0.4356 | alpha_mean=0.699
# [alpha_0.05_1.00_beta_1.5] Epoch 029 | trainCE=0.15960 | valCE=0.08595 | PixelIoU=0.7180 | LineIU=0.7885 | DR=0.5158 | RA=0.2979 | FM=0.3706 | alpha_mean=0.689
# [alpha_0.05_1.00_beta_1.5] Epoch 030 | trainCE=0.17538 | valCE=0.08738 | PixelIoU=0.7219 | LineIU=0.8105 | DR=0.5712 | RA=0.3487 | FM=0.4237 | alpha_mean=0.712
# [alpha_0.05_1.00_beta_1.5] Epoch 031 | trainCE=0.18455 | valCE=0.08359 | PixelIoU=0.7277 | LineIU=0.7727 | DR=0.5746 | RA=0.3219 | FM=0.4047 | alpha_mean=0.703
# [alpha_0.05_1.00_beta_1.5] Epoch 032 | trainCE=0.16473 | valCE=0.08391 | PixelIoU=0.7238 | LineIU=0.7973 | DR=0.5754 | RA=0.3470 | FM=0.4244 | alpha_mean=0.708
# [alpha_0.05_1.00_beta_1.5] Epoch 033 | trainCE=0.15546 | valCE=0.08384 | PixelIoU=0.7202 | LineIU=0.7971 | DR=0.5474 | RA=0.3279 | FM=0.4015 | alpha_mean=0.711
# [alpha_0.05_1.00_beta_1.5] Epoch 034 | trainCE=0.16045 | valCE=0.08324 | PixelIoU=0.7228 | LineIU=0.7991 | DR=0.5609 | RA=0.3240 | FM=0.4026 | alpha_mean=0.711
# [alpha_0.05_1.00_beta_1.5] Epoch 035 | trainCE=0.14640 | valCE=0.08289 | PixelIoU=0.7237 | LineIU=0.7833 | DR=0.5437 | RA=0.2951 | FM=0.3757 | alpha_mean=0.728
# [alpha_0.05_1.00_beta_1.5] Epoch 036 | trainCE=0.16682 | valCE=0.08304 | PixelIoU=0.7272 | LineIU=0.7998 | DR=0.5910 | RA=0.3422 | FM=0.4256 | alpha_mean=0.733
# [alpha_0.05_1.00_beta_1.5] Epoch 037 | trainCE=0.17058 | valCE=0.08502 | PixelIoU=0.7248 | LineIU=0.8036 | DR=0.5917 | RA=0.3765 | FM=0.4510 | alpha_mean=0.737
# [alpha_0.05_1.00_beta_1.5] Epoch 038 | trainCE=0.15131 | valCE=0.08352 | PixelIoU=0.7282 | LineIU=0.7934 | DR=0.6058 | RA=0.3550 | FM=0.4386 | alpha_mean=0.735
# [alpha_0.05_1.00_beta_1.5] Epoch 039 | trainCE=0.14742 | valCE=0.08301 | PixelIoU=0.7255 | LineIU=0.8163 | DR=0.5842 | RA=0.3467 | FM=0.4264 | alpha_mean=0.749
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.8163
# [alpha_0.05_1.00_beta_1.5] Epoch 040 | trainCE=0.15410 | valCE=0.08567 | PixelIoU=0.7250 | LineIU=0.8026 | DR=0.5920 | RA=0.3424 | FM=0.4247 | alpha_mean=0.767
# [alpha_0.05_1.00_beta_1.5] Epoch 041 | trainCE=0.17182 | valCE=0.08050 | PixelIoU=0.7302 | LineIU=0.7726 | DR=0.5894 | RA=0.3140 | FM=0.4015 | alpha_mean=0.746
# [alpha_0.05_1.00_beta_1.5] Epoch 042 | trainCE=0.16334 | valCE=0.08209 | PixelIoU=0.7290 | LineIU=0.8255 | DR=0.6021 | RA=0.3482 | FM=0.4335 | alpha_mean=0.759
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.8255
# [alpha_0.05_1.00_beta_1.5] Epoch 043 | trainCE=0.15461 | valCE=0.08013 | PixelIoU=0.7328 | LineIU=0.7862 | DR=0.6065 | RA=0.3359 | FM=0.4245 | alpha_mean=0.747
# [alpha_0.05_1.00_beta_1.5] Epoch 044 | trainCE=0.15022 | valCE=0.07914 | PixelIoU=0.7382 | LineIU=0.8224 | DR=0.6625 | RA=0.3721 | FM=0.4673 | alpha_mean=0.759
# [alpha_0.05_1.00_beta_1.5] Epoch 045 | trainCE=0.15519 | valCE=0.07985 | PixelIoU=0.7316 | LineIU=0.8254 | DR=0.6158 | RA=0.3412 | FM=0.4313 | alpha_mean=0.757
# [alpha_0.05_1.00_beta_1.5] Epoch 046 | trainCE=0.15308 | valCE=0.07876 | PixelIoU=0.7436 | LineIU=0.8311 | DR=0.6774 | RA=0.3729 | FM=0.4717 | alpha_mean=0.758
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.8311
# [alpha_0.05_1.00_beta_1.5] Epoch 047 | trainCE=0.16345 | valCE=0.07745 | PixelIoU=0.7391 | LineIU=0.8076 | DR=0.6326 | RA=0.3183 | FM=0.4158 | alpha_mean=0.761
# [alpha_0.05_1.00_beta_1.5] Epoch 048 | trainCE=0.14969 | valCE=0.07896 | PixelIoU=0.7444 | LineIU=0.8466 | DR=0.6977 | RA=0.3938 | FM=0.4937 | alpha_mean=0.777
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.8466
# [alpha_0.05_1.00_beta_1.5] Epoch 049 | trainCE=0.16080 | valCE=0.07944 | PixelIoU=0.7540 | LineIU=0.8470 | DR=0.7105 | RA=0.4092 | FM=0.5075 | alpha_mean=0.772
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.8470
# [alpha_0.05_1.00_beta_1.5] Epoch 050 | trainCE=0.15061 | valCE=0.07514 | PixelIoU=0.7665 | LineIU=0.8729 | DR=0.7680 | RA=0.3986 | FM=0.5133 | alpha_mean=0.766
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.8729
# [alpha_0.05_1.00_beta_1.5] Epoch 051 | trainCE=0.14867 | valCE=0.07587 | PixelIoU=0.7672 | LineIU=0.8830 | DR=0.7848 | RA=0.4200 | FM=0.5344 | alpha_mean=0.766
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.8830
# [alpha_0.05_1.00_beta_1.5] Epoch 052 | trainCE=0.14026 | valCE=0.07485 | PixelIoU=0.7845 | LineIU=0.8939 | DR=0.8035 | RA=0.4130 | FM=0.5334 | alpha_mean=0.778
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.8939
# [alpha_0.05_1.00_beta_1.5] Epoch 053 | trainCE=0.14719 | valCE=0.07344 | PixelIoU=0.7889 | LineIU=0.8921 | DR=0.8195 | RA=0.4185 | FM=0.5409 | alpha_mean=0.778
# [alpha_0.05_1.00_beta_1.5] Epoch 054 | trainCE=0.14301 | valCE=0.07275 | PixelIoU=0.7883 | LineIU=0.8831 | DR=0.8084 | RA=0.3949 | FM=0.5188 | alpha_mean=0.781
# [alpha_0.05_1.00_beta_1.5] Epoch 055 | trainCE=0.13905 | valCE=0.07194 | PixelIoU=0.7958 | LineIU=0.9040 | DR=0.8275 | RA=0.4179 | FM=0.5421 | alpha_mean=0.778
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.9040
# [alpha_0.05_1.00_beta_1.5] Epoch 056 | trainCE=0.13436 | valCE=0.07644 | PixelIoU=0.7979 | LineIU=0.8983 | DR=0.8225 | RA=0.4148 | FM=0.5392 | alpha_mean=0.795
# [alpha_0.05_1.00_beta_1.5] Epoch 057 | trainCE=0.12908 | valCE=0.07622 | PixelIoU=0.7946 | LineIU=0.8965 | DR=0.8316 | RA=0.4108 | FM=0.5379 | alpha_mean=0.793
# [alpha_0.05_1.00_beta_1.5] Epoch 058 | trainCE=0.13473 | valCE=0.07539 | PixelIoU=0.8022 | LineIU=0.8894 | DR=0.8165 | RA=0.4097 | FM=0.5334 | alpha_mean=0.780
# [alpha_0.05_1.00_beta_1.5] Epoch 059 | trainCE=0.10909 | valCE=0.07446 | PixelIoU=0.8030 | LineIU=0.9173 | DR=0.8622 | RA=0.4225 | FM=0.5549 | alpha_mean=0.789
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.9173
# [alpha_0.05_1.00_beta_1.5] Epoch 060 | trainCE=0.12261 | valCE=0.07368 | PixelIoU=0.8078 | LineIU=0.9032 | DR=0.8506 | RA=0.4087 | FM=0.5403 | alpha_mean=0.779
# [alpha_0.05_1.00_beta_1.5] Epoch 061 | trainCE=0.13185 | valCE=0.07170 | PixelIoU=0.8071 | LineIU=0.8947 | DR=0.8303 | RA=0.4051 | FM=0.5324 | alpha_mean=0.786
# [alpha_0.05_1.00_beta_1.5] Epoch 062 | trainCE=0.12810 | valCE=0.07248 | PixelIoU=0.8060 | LineIU=0.9135 | DR=0.8690 | RA=0.3912 | FM=0.5276 | alpha_mean=0.784
# [alpha_0.05_1.00_beta_1.5] Epoch 063 | trainCE=0.11809 | valCE=0.07573 | PixelIoU=0.8098 | LineIU=0.8938 | DR=0.8315 | RA=0.4114 | FM=0.5392 | alpha_mean=0.798
# [alpha_0.05_1.00_beta_1.5] Epoch 064 | trainCE=0.11894 | valCE=0.07248 | PixelIoU=0.8174 | LineIU=0.9072 | DR=0.8491 | RA=0.4000 | FM=0.5342 | alpha_mean=0.789
# [alpha_0.05_1.00_beta_1.5] Epoch 065 | trainCE=0.13125 | valCE=0.07155 | PixelIoU=0.8152 | LineIU=0.9027 | DR=0.8558 | RA=0.4018 | FM=0.5366 | alpha_mean=0.782
# [alpha_0.05_1.00_beta_1.5] Epoch 066 | trainCE=0.11648 | valCE=0.07470 | PixelIoU=0.8176 | LineIU=0.9022 | DR=0.8556 | RA=0.3943 | FM=0.5297 | alpha_mean=0.806
# [alpha_0.05_1.00_beta_1.5] Epoch 067 | trainCE=0.12001 | valCE=0.07172 | PixelIoU=0.8199 | LineIU=0.9257 | DR=0.8774 | RA=0.3972 | FM=0.5361 | alpha_mean=0.794
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.9257
# [alpha_0.05_1.00_beta_1.5] Epoch 068 | trainCE=0.11654 | valCE=0.07450 | PixelIoU=0.8125 | LineIU=0.9091 | DR=0.8716 | RA=0.3776 | FM=0.5158 | alpha_mean=0.785
# [alpha_0.05_1.00_beta_1.5] Epoch 069 | trainCE=0.12037 | valCE=0.07229 | PixelIoU=0.8164 | LineIU=0.9088 | DR=0.8592 | RA=0.3845 | FM=0.5215 | alpha_mean=0.799
# [alpha_0.05_1.00_beta_1.5] Epoch 070 | trainCE=0.11184 | valCE=0.07083 | PixelIoU=0.8259 | LineIU=0.9236 | DR=0.8775 | RA=0.3927 | FM=0.5330 | alpha_mean=0.802
# [alpha_0.05_1.00_beta_1.5] Epoch 071 | trainCE=0.10526 | valCE=0.07461 | PixelIoU=0.8224 | LineIU=0.9256 | DR=0.8782 | RA=0.3985 | FM=0.5382 | alpha_mean=0.799
# [alpha_0.05_1.00_beta_1.5] Epoch 072 | trainCE=0.10044 | valCE=0.07145 | PixelIoU=0.8188 | LineIU=0.9234 | DR=0.8684 | RA=0.3769 | FM=0.5157 | alpha_mean=0.806
# [alpha_0.05_1.00_beta_1.5] Epoch 073 | trainCE=0.11964 | valCE=0.07442 | PixelIoU=0.8178 | LineIU=0.8936 | DR=0.8581 | RA=0.3978 | FM=0.5344 | alpha_mean=0.803
# [alpha_0.05_1.00_beta_1.5] Epoch 074 | trainCE=0.11437 | valCE=0.07241 | PixelIoU=0.8202 | LineIU=0.9234 | DR=0.8769 | RA=0.3889 | FM=0.5295 | alpha_mean=0.810
# [alpha_0.05_1.00_beta_1.5] Epoch 075 | trainCE=0.11500 | valCE=0.07392 | PixelIoU=0.8230 | LineIU=0.9073 | DR=0.8702 | RA=0.3925 | FM=0.5318 | alpha_mean=0.809
# [alpha_0.05_1.00_beta_1.5] Epoch 076 | trainCE=0.11268 | valCE=0.07063 | PixelIoU=0.8238 | LineIU=0.9098 | DR=0.8677 | RA=0.3958 | FM=0.5345 | alpha_mean=0.809
# [alpha_0.05_1.00_beta_1.5] Epoch 077 | trainCE=0.11267 | valCE=0.07412 | PixelIoU=0.8225 | LineIU=0.9140 | DR=0.8668 | RA=0.3842 | FM=0.5228 | alpha_mean=0.824
# [alpha_0.05_1.00_beta_1.5] Epoch 078 | trainCE=0.11950 | valCE=0.07216 | PixelIoU=0.8231 | LineIU=0.9155 | DR=0.8783 | RA=0.3916 | FM=0.5306 | alpha_mean=0.818
# [alpha_0.05_1.00_beta_1.5] Epoch 079 | trainCE=0.10968 | valCE=0.07096 | PixelIoU=0.8254 | LineIU=0.9111 | DR=0.8776 | RA=0.3834 | FM=0.5247 | alpha_mean=0.826
# [alpha_0.05_1.00_beta_1.5] Epoch 080 | trainCE=0.11480 | valCE=0.07071 | PixelIoU=0.8290 | LineIU=0.9293 | DR=0.8833 | RA=0.3950 | FM=0.5366 | alpha_mean=0.816
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.9293
# [alpha_0.05_1.00_beta_1.5] Epoch 081 | trainCE=0.11228 | valCE=0.07225 | PixelIoU=0.8288 | LineIU=0.9131 | DR=0.8632 | RA=0.3859 | FM=0.5240 | alpha_mean=0.827
# [alpha_0.05_1.00_beta_1.5] Epoch 082 | trainCE=0.10678 | valCE=0.07708 | PixelIoU=0.8231 | LineIU=0.8919 | DR=0.8541 | RA=0.4121 | FM=0.5467 | alpha_mean=0.829
# [alpha_0.05_1.00_beta_1.5] Epoch 083 | trainCE=0.11411 | valCE=0.07486 | PixelIoU=0.8271 | LineIU=0.8999 | DR=0.8638 | RA=0.3992 | FM=0.5359 | alpha_mean=0.825
# [alpha_0.05_1.00_beta_1.5] Epoch 084 | trainCE=0.10685 | valCE=0.07365 | PixelIoU=0.8296 | LineIU=0.9029 | DR=0.8710 | RA=0.4118 | FM=0.5488 | alpha_mean=0.828
# [alpha_0.05_1.00_beta_1.5] Epoch 085 | trainCE=0.10811 | valCE=0.07521 | PixelIoU=0.8230 | LineIU=0.9199 | DR=0.8823 | RA=0.4102 | FM=0.5498 | alpha_mean=0.831
# [alpha_0.05_1.00_beta_1.5] Epoch 086 | trainCE=0.11379 | valCE=0.07073 | PixelIoU=0.8320 | LineIU=0.9255 | DR=0.8790 | RA=0.3985 | FM=0.5387 | alpha_mean=0.828
# [alpha_0.05_1.00_beta_1.5] Epoch 087 | trainCE=0.10632 | valCE=0.07304 | PixelIoU=0.8290 | LineIU=0.9226 | DR=0.8802 | RA=0.3837 | FM=0.5241 | alpha_mean=0.832
# [alpha_0.05_1.00_beta_1.5] Epoch 088 | trainCE=0.10669 | valCE=0.07366 | PixelIoU=0.8282 | LineIU=0.9204 | DR=0.8730 | RA=0.3886 | FM=0.5288 | alpha_mean=0.830
# [alpha_0.05_1.00_beta_1.5] Epoch 089 | trainCE=0.10973 | valCE=0.07504 | PixelIoU=0.8266 | LineIU=0.8958 | DR=0.8603 | RA=0.3977 | FM=0.5350 | alpha_mean=0.829
# [alpha_0.05_1.00_beta_1.5] Epoch 090 | trainCE=0.10965 | valCE=0.07224 | PixelIoU=0.8306 | LineIU=0.9252 | DR=0.8909 | RA=0.3767 | FM=0.5193 | alpha_mean=0.837
# [alpha_0.05_1.00_beta_1.5] Epoch 091 | trainCE=0.10285 | valCE=0.07879 | PixelIoU=0.8257 | LineIU=0.8935 | DR=0.8462 | RA=0.3985 | FM=0.5336 | alpha_mean=0.841
# [alpha_0.05_1.00_beta_1.5] Epoch 092 | trainCE=0.10868 | valCE=0.07723 | PixelIoU=0.8260 | LineIU=0.8960 | DR=0.8645 | RA=0.4221 | FM=0.5588 | alpha_mean=0.843
# [alpha_0.05_1.00_beta_1.5] Epoch 093 | trainCE=0.10456 | valCE=0.07431 | PixelIoU=0.8286 | LineIU=0.8976 | DR=0.8684 | RA=0.4104 | FM=0.5475 | alpha_mean=0.837
# [alpha_0.05_1.00_beta_1.5] Epoch 094 | trainCE=0.10835 | valCE=0.07452 | PixelIoU=0.8226 | LineIU=0.9288 | DR=0.8875 | RA=0.4119 | FM=0.5515 | alpha_mean=0.836
# [alpha_0.05_1.00_beta_1.5] Epoch 095 | trainCE=0.10409 | valCE=0.07974 | PixelIoU=0.8213 | LineIU=0.8938 | DR=0.8600 | RA=0.4083 | FM=0.5448 | alpha_mean=0.843
# [alpha_0.05_1.00_beta_1.5] Epoch 096 | trainCE=0.10094 | valCE=0.07142 | PixelIoU=0.8342 | LineIU=0.9299 | DR=0.8829 | RA=0.4073 | FM=0.5472 | alpha_mean=0.839
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.9299
# [alpha_0.05_1.00_beta_1.5] Epoch 097 | trainCE=0.10320 | valCE=0.07076 | PixelIoU=0.8294 | LineIU=0.9247 | DR=0.8832 | RA=0.3867 | FM=0.5283 | alpha_mean=0.837
# [alpha_0.05_1.00_beta_1.5] Epoch 098 | trainCE=0.10663 | valCE=0.07350 | PixelIoU=0.8308 | LineIU=0.9140 | DR=0.8772 | RA=0.4260 | FM=0.5644 | alpha_mean=0.844
# [alpha_0.05_1.00_beta_1.5] Epoch 099 | trainCE=0.11416 | valCE=0.07102 | PixelIoU=0.8298 | LineIU=0.9304 | DR=0.8892 | RA=0.4199 | FM=0.5599 | alpha_mean=0.846
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.9304
# [alpha_0.05_1.00_beta_1.5] Epoch 100 | trainCE=0.10123 | valCE=0.07561 | PixelIoU=0.8296 | LineIU=0.9089 | DR=0.8610 | RA=0.3947 | FM=0.5340 | alpha_mean=0.843
# [alpha_0.05_1.00_beta_1.5] Epoch 101 | trainCE=0.11315 | valCE=0.07358 | PixelIoU=0.8307 | LineIU=0.9271 | DR=0.8866 | RA=0.4250 | FM=0.5641 | alpha_mean=0.849
# [alpha_0.05_1.00_beta_1.5] Epoch 102 | trainCE=0.10809 | valCE=0.07811 | PixelIoU=0.8261 | LineIU=0.9016 | DR=0.8640 | RA=0.4199 | FM=0.5560 | alpha_mean=0.850
# [alpha_0.05_1.00_beta_1.5] Epoch 103 | trainCE=0.10092 | valCE=0.07061 | PixelIoU=0.8347 | LineIU=0.9290 | DR=0.8913 | RA=0.4318 | FM=0.5704 | alpha_mean=0.846
# [alpha_0.05_1.00_beta_1.5] Epoch 104 | trainCE=0.10322 | valCE=0.07995 | PixelIoU=0.8244 | LineIU=0.8926 | DR=0.8591 | RA=0.4010 | FM=0.5374 | alpha_mean=0.851
# [alpha_0.05_1.00_beta_1.5] Epoch 105 | trainCE=0.10158 | valCE=0.07351 | PixelIoU=0.8294 | LineIU=0.9178 | DR=0.8792 | RA=0.4248 | FM=0.5613 | alpha_mean=0.855
# [alpha_0.05_1.00_beta_1.5] Epoch 106 | trainCE=0.10509 | valCE=0.07504 | PixelIoU=0.8292 | LineIU=0.9089 | DR=0.8680 | RA=0.4503 | FM=0.5823 | alpha_mean=0.851
# [alpha_0.05_1.00_beta_1.5] Epoch 107 | trainCE=0.09735 | valCE=0.07334 | PixelIoU=0.8265 | LineIU=0.8863 | DR=0.8497 | RA=0.4408 | FM=0.5690 | alpha_mean=0.848
# [alpha_0.05_1.00_beta_1.5] Epoch 108 | trainCE=0.09370 | valCE=0.07457 | PixelIoU=0.8276 | LineIU=0.9092 | DR=0.8746 | RA=0.4544 | FM=0.5862 | alpha_mean=0.847
# [alpha_0.05_1.00_beta_1.5] Epoch 109 | trainCE=0.09824 | valCE=0.07507 | PixelIoU=0.8264 | LineIU=0.9068 | DR=0.8692 | RA=0.4653 | FM=0.5930 | alpha_mean=0.854
# [alpha_0.05_1.00_beta_1.5] Epoch 110 | trainCE=0.10859 | valCE=0.07185 | PixelIoU=0.8308 | LineIU=0.9137 | DR=0.8844 | RA=0.3974 | FM=0.5372 | alpha_mean=0.847
# [alpha_0.05_1.00_beta_1.5] Epoch 111 | trainCE=0.09901 | valCE=0.07582 | PixelIoU=0.8299 | LineIU=0.8994 | DR=0.8603 | RA=0.4112 | FM=0.5455 | alpha_mean=0.851
# [alpha_0.05_1.00_beta_1.5] Epoch 112 | trainCE=0.09919 | valCE=0.07085 | PixelIoU=0.8294 | LineIU=0.9121 | DR=0.8830 | RA=0.4597 | FM=0.5898 | alpha_mean=0.846
# [alpha_0.05_1.00_beta_1.5] Epoch 113 | trainCE=0.10421 | valCE=0.07350 | PixelIoU=0.8269 | LineIU=0.9182 | DR=0.8695 | RA=0.4392 | FM=0.5709 | alpha_mean=0.849
# [alpha_0.05_1.00_beta_1.5] Epoch 114 | trainCE=0.09671 | valCE=0.07732 | PixelIoU=0.8279 | LineIU=0.8951 | DR=0.8650 | RA=0.4529 | FM=0.5833 | alpha_mean=0.856
# [alpha_0.05_1.00_beta_1.5] Epoch 115 | trainCE=0.10200 | valCE=0.07601 | PixelIoU=0.8264 | LineIU=0.8937 | DR=0.8574 | RA=0.4563 | FM=0.5835 | alpha_mean=0.858
# [alpha_0.05_1.00_beta_1.5] Epoch 116 | trainCE=0.09622 | valCE=0.07337 | PixelIoU=0.8341 | LineIU=0.9290 | DR=0.8949 | RA=0.4674 | FM=0.6014 | alpha_mean=0.861
# [alpha_0.05_1.00_beta_1.5] Epoch 117 | trainCE=0.10561 | valCE=0.07342 | PixelIoU=0.8306 | LineIU=0.9143 | DR=0.8819 | RA=0.4658 | FM=0.5955 | alpha_mean=0.850
# [alpha_0.05_1.00_beta_1.5] Epoch 118 | trainCE=0.09846 | valCE=0.07284 | PixelIoU=0.8285 | LineIU=0.9189 | DR=0.8837 | RA=0.4164 | FM=0.5529 | alpha_mean=0.848
# [alpha_0.05_1.00_beta_1.5] Epoch 119 | trainCE=0.10277 | valCE=0.07233 | PixelIoU=0.8348 | LineIU=0.9002 | DR=0.8616 | RA=0.4455 | FM=0.5747 | alpha_mean=0.859
# [alpha_0.05_1.00_beta_1.5] Epoch 120 | trainCE=0.10713 | valCE=0.07321 | PixelIoU=0.8328 | LineIU=0.9156 | DR=0.8900 | RA=0.4714 | FM=0.6016 | alpha_mean=0.855
# [alpha_0.05_1.00_beta_1.5] Epoch 121 | trainCE=0.09702 | valCE=0.07515 | PixelIoU=0.8308 | LineIU=0.8984 | DR=0.8577 | RA=0.4601 | FM=0.5875 | alpha_mean=0.864
# [alpha_0.05_1.00_beta_1.5] Epoch 122 | trainCE=0.10379 | valCE=0.07023 | PixelIoU=0.8345 | LineIU=0.9094 | DR=0.8756 | RA=0.4729 | FM=0.5999 | alpha_mean=0.862
# [alpha_0.05_1.00_beta_1.5] Epoch 123 | trainCE=0.09787 | valCE=0.07496 | PixelIoU=0.8326 | LineIU=0.9094 | DR=0.8771 | RA=0.4628 | FM=0.5943 | alpha_mean=0.861
# [alpha_0.05_1.00_beta_1.5] Epoch 124 | trainCE=0.09043 | valCE=0.07421 | PixelIoU=0.8331 | LineIU=0.9074 | DR=0.8688 | RA=0.4472 | FM=0.5771 | alpha_mean=0.862
# [alpha_0.05_1.00_beta_1.5] Epoch 125 | trainCE=0.09721 | valCE=0.07640 | PixelIoU=0.8261 | LineIU=0.8971 | DR=0.8673 | RA=0.4241 | FM=0.5585 | alpha_mean=0.858
# [alpha_0.05_1.00_beta_1.5] Epoch 126 | trainCE=0.10442 | valCE=0.07297 | PixelIoU=0.8346 | LineIU=0.9076 | DR=0.8740 | RA=0.4616 | FM=0.5910 | alpha_mean=0.856
# [alpha_0.05_1.00_beta_1.5] Epoch 127 | trainCE=0.10095 | valCE=0.07524 | PixelIoU=0.8310 | LineIU=0.9010 | DR=0.8696 | RA=0.4450 | FM=0.5762 | alpha_mean=0.860
# [alpha_0.05_1.00_beta_1.5] Epoch 128 | trainCE=0.09811 | valCE=0.07810 | PixelIoU=0.8289 | LineIU=0.8912 | DR=0.8687 | RA=0.4647 | FM=0.5930 | alpha_mean=0.869
# [alpha_0.05_1.00_beta_1.5] Epoch 129 | trainCE=0.09586 | valCE=0.07399 | PixelIoU=0.8331 | LineIU=0.9061 | DR=0.8772 | RA=0.4459 | FM=0.5759 | alpha_mean=0.861
# [alpha_0.05_1.00_beta_1.5] Epoch 130 | trainCE=0.09588 | valCE=0.07445 | PixelIoU=0.8341 | LineIU=0.8800 | DR=0.8522 | RA=0.4348 | FM=0.5628 | alpha_mean=0.862
# [alpha_0.05_1.00_beta_1.5] Epoch 131 | trainCE=0.09665 | valCE=0.07301 | PixelIoU=0.8339 | LineIU=0.8907 | DR=0.8602 | RA=0.4380 | FM=0.5680 | alpha_mean=0.868
# [alpha_0.05_1.00_beta_1.5] Epoch 132 | trainCE=0.09285 | valCE=0.07005 | PixelIoU=0.8382 | LineIU=0.9198 | DR=0.8863 | RA=0.4591 | FM=0.5901 | alpha_mean=0.863
# [alpha_0.05_1.00_beta_1.5] Epoch 133 | trainCE=0.10146 | valCE=0.07333 | PixelIoU=0.8356 | LineIU=0.8905 | DR=0.8592 | RA=0.4619 | FM=0.5873 | alpha_mean=0.869
# [alpha_0.05_1.00_beta_1.5] Epoch 134 | trainCE=0.09960 | valCE=0.07222 | PixelIoU=0.8350 | LineIU=0.8958 | DR=0.8706 | RA=0.4627 | FM=0.5916 | alpha_mean=0.868
# [alpha_0.05_1.00_beta_1.5] Epoch 135 | trainCE=0.10600 | valCE=0.07482 | PixelIoU=0.8319 | LineIU=0.8852 | DR=0.8444 | RA=0.4674 | FM=0.5887 | alpha_mean=0.872
# [alpha_0.05_1.00_beta_1.5] Epoch 136 | trainCE=0.09358 | valCE=0.07437 | PixelIoU=0.8302 | LineIU=0.9164 | DR=0.8663 | RA=0.4727 | FM=0.5991 | alpha_mean=0.869
# [alpha_0.05_1.00_beta_1.5] Epoch 137 | trainCE=0.10295 | valCE=0.07528 | PixelIoU=0.8333 | LineIU=0.8841 | DR=0.8527 | RA=0.4590 | FM=0.5838 | alpha_mean=0.865
# [alpha_0.05_1.00_beta_1.5] Epoch 138 | trainCE=0.09391 | valCE=0.07599 | PixelIoU=0.8328 | LineIU=0.9003 | DR=0.8703 | RA=0.4418 | FM=0.5744 | alpha_mean=0.869
# [alpha_0.05_1.00_beta_1.5] Epoch 139 | trainCE=0.09600 | valCE=0.07531 | PixelIoU=0.8336 | LineIU=0.9106 | DR=0.8837 | RA=0.4693 | FM=0.5996 | alpha_mean=0.874
# [alpha_0.05_1.00_beta_1.5] Epoch 140 | trainCE=0.09697 | valCE=0.07342 | PixelIoU=0.8370 | LineIU=0.9085 | DR=0.8710 | RA=0.4687 | FM=0.5968 | alpha_mean=0.872
# [alpha_0.05_1.00_beta_1.5] Epoch 141 | trainCE=0.09905 | valCE=0.07470 | PixelIoU=0.8343 | LineIU=0.8901 | DR=0.8637 | RA=0.4501 | FM=0.5793 | alpha_mean=0.872
# [alpha_0.05_1.00_beta_1.5] Epoch 142 | trainCE=0.09133 | valCE=0.07674 | PixelIoU=0.8335 | LineIU=0.9025 | DR=0.8683 | RA=0.4575 | FM=0.5864 | alpha_mean=0.870
# [alpha_0.05_1.00_beta_1.5] Epoch 143 | trainCE=0.09665 | valCE=0.07147 | PixelIoU=0.8356 | LineIU=0.8839 | DR=0.8528 | RA=0.4451 | FM=0.5714 | alpha_mean=0.870
# [alpha_0.05_1.00_beta_1.5] Epoch 144 | trainCE=0.09017 | valCE=0.07448 | PixelIoU=0.8330 | LineIU=0.8830 | DR=0.8536 | RA=0.4527 | FM=0.5783 | alpha_mean=0.870
# [alpha_0.05_1.00_beta_1.5] Epoch 145 | trainCE=0.09239 | valCE=0.07274 | PixelIoU=0.8363 | LineIU=0.8947 | DR=0.8681 | RA=0.4684 | FM=0.5957 | alpha_mean=0.875
# [alpha_0.05_1.00_beta_1.5] Epoch 146 | trainCE=0.09416 | valCE=0.07597 | PixelIoU=0.8356 | LineIU=0.8923 | DR=0.8617 | RA=0.4521 | FM=0.5807 | alpha_mean=0.867
# [alpha_0.05_1.00_beta_1.5] Epoch 147 | trainCE=0.09683 | valCE=0.07329 | PixelIoU=0.8335 | LineIU=0.8951 | DR=0.8646 | RA=0.4628 | FM=0.5899 | alpha_mean=0.874
# [alpha_0.05_1.00_beta_1.5] Epoch 148 | trainCE=0.09257 | valCE=0.07890 | PixelIoU=0.8314 | LineIU=0.8885 | DR=0.8648 | RA=0.4581 | FM=0.5860 | alpha_mean=0.873
# [alpha_0.05_1.00_beta_1.5] Epoch 149 | trainCE=0.09162 | valCE=0.07522 | PixelIoU=0.8361 | LineIU=0.8900 | DR=0.8582 | RA=0.4885 | FM=0.6113 | alpha_mean=0.882
# [alpha_0.05_1.00_beta_1.5] Epoch 150 | trainCE=0.09336 | valCE=0.07551 | PixelIoU=0.8356 | LineIU=0.8975 | DR=0.8651 | RA=0.4674 | FM=0.5945 | alpha_mean=0.871
# [alpha_0.05_1.00_beta_1.5] Epoch 151 | trainCE=0.09695 | valCE=0.07464 | PixelIoU=0.8358 | LineIU=0.8954 | DR=0.8669 | RA=0.4546 | FM=0.5829 | alpha_mean=0.875
# [alpha_0.05_1.00_beta_1.5] Epoch 152 | trainCE=0.10041 | valCE=0.07693 | PixelIoU=0.8344 | LineIU=0.8918 | DR=0.8639 | RA=0.4805 | FM=0.6048 | alpha_mean=0.877
# [alpha_0.05_1.00_beta_1.5] Epoch 153 | trainCE=0.08958 | valCE=0.07509 | PixelIoU=0.8302 | LineIU=0.8986 | DR=0.8654 | RA=0.4631 | FM=0.5903 | alpha_mean=0.871
# [alpha_0.05_1.00_beta_1.5] Epoch 154 | trainCE=0.08972 | valCE=0.07730 | PixelIoU=0.8338 | LineIU=0.8918 | DR=0.8580 | RA=0.4801 | FM=0.6037 | alpha_mean=0.881
# [alpha_0.05_1.00_beta_1.5] Epoch 155 | trainCE=0.09928 | valCE=0.07595 | PixelIoU=0.8343 | LineIU=0.8881 | DR=0.8619 | RA=0.4675 | FM=0.5946 | alpha_mean=0.875
# [alpha_0.05_1.00_beta_1.5] Epoch 156 | trainCE=0.09436 | valCE=0.07733 | PixelIoU=0.8345 | LineIU=0.8878 | DR=0.8586 | RA=0.4437 | FM=0.5730 | alpha_mean=0.879
# [alpha_0.05_1.00_beta_1.5] Epoch 157 | trainCE=0.07092 | valCE=0.07600 | PixelIoU=0.8354 | LineIU=0.8953 | DR=0.8663 | RA=0.4782 | FM=0.6038 | alpha_mean=0.875
# [alpha_0.05_1.00_beta_1.5] Epoch 158 | trainCE=0.08633 | valCE=0.07486 | PixelIoU=0.8337 | LineIU=0.8840 | DR=0.8532 | RA=0.4518 | FM=0.5788 | alpha_mean=0.877
# [alpha_0.05_1.00_beta_1.5] Epoch 159 | trainCE=0.08119 | valCE=0.07539 | PixelIoU=0.8373 | LineIU=0.9117 | DR=0.8830 | RA=0.4718 | FM=0.6013 | alpha_mean=0.870
# [alpha_0.05_1.00_beta_1.5] Epoch 160 | trainCE=0.08916 | valCE=0.07731 | PixelIoU=0.8329 | LineIU=0.8911 | DR=0.8670 | RA=0.4594 | FM=0.5882 | alpha_mean=0.879
# [alpha_0.05_1.00_beta_1.5] Epoch 161 | trainCE=0.09146 | valCE=0.07744 | PixelIoU=0.8329 | LineIU=0.9027 | DR=0.8710 | RA=0.4829 | FM=0.6082 | alpha_mean=0.874
# [alpha_0.05_1.00_beta_1.5] Epoch 162 | trainCE=0.09398 | valCE=0.07802 | PixelIoU=0.8323 | LineIU=0.8800 | DR=0.8543 | RA=0.4677 | FM=0.5940 | alpha_mean=0.880
# [alpha_0.05_1.00_beta_1.5] Epoch 163 | trainCE=0.10123 | valCE=0.07624 | PixelIoU=0.8332 | LineIU=0.8900 | DR=0.8561 | RA=0.4616 | FM=0.5866 | alpha_mean=0.877
# [alpha_0.05_1.00_beta_1.5] Epoch 164 | trainCE=0.07956 | valCE=0.07770 | PixelIoU=0.8316 | LineIU=0.9001 | DR=0.8653 | RA=0.4600 | FM=0.5884 | alpha_mean=0.873
# [alpha_0.05_1.00_beta_1.5] Epoch 165 | trainCE=0.08508 | valCE=0.07681 | PixelIoU=0.8316 | LineIU=0.8897 | DR=0.8559 | RA=0.4582 | FM=0.5839 | alpha_mean=0.872
# [alpha_0.05_1.00_beta_1.5] Epoch 166 | trainCE=0.08538 | valCE=0.07670 | PixelIoU=0.8340 | LineIU=0.8911 | DR=0.8592 | RA=0.4723 | FM=0.5971 | alpha_mean=0.878
# [alpha_0.05_1.00_beta_1.5] Epoch 167 | trainCE=0.09162 | valCE=0.07485 | PixelIoU=0.8368 | LineIU=0.9112 | DR=0.8791 | RA=0.4753 | FM=0.6027 | alpha_mean=0.878
# [alpha_0.05_1.00_beta_1.5] Epoch 168 | trainCE=0.08479 | valCE=0.07516 | PixelIoU=0.8377 | LineIU=0.8996 | DR=0.8687 | RA=0.4803 | FM=0.6048 | alpha_mean=0.878
# [alpha_0.05_1.00_beta_1.5] Epoch 169 | trainCE=0.09063 | valCE=0.07798 | PixelIoU=0.8303 | LineIU=0.8826 | DR=0.8512 | RA=0.4516 | FM=0.5771 | alpha_mean=0.877
# [alpha_0.05_1.00_beta_1.5] Epoch 170 | trainCE=0.09145 | valCE=0.07913 | PixelIoU=0.8314 | LineIU=0.8792 | DR=0.8485 | RA=0.4542 | FM=0.5789 | alpha_mean=0.874
# [alpha_0.05_1.00_beta_1.5] Epoch 171 | trainCE=0.09209 | valCE=0.08056 | PixelIoU=0.8299 | LineIU=0.8856 | DR=0.8575 | RA=0.4797 | FM=0.6038 | alpha_mean=0.878
# [alpha_0.05_1.00_beta_1.5] Epoch 172 | trainCE=0.09586 | valCE=0.07988 | PixelIoU=0.8313 | LineIU=0.8837 | DR=0.8531 | RA=0.4697 | FM=0.5943 | alpha_mean=0.881
# [alpha_0.05_1.00_beta_1.5] Epoch 173 | trainCE=0.08544 | valCE=0.07780 | PixelIoU=0.8333 | LineIU=0.8928 | DR=0.8634 | RA=0.4733 | FM=0.5993 | alpha_mean=0.881
# [alpha_0.05_1.00_beta_1.5] Epoch 174 | trainCE=0.08726 | valCE=0.07704 | PixelIoU=0.8350 | LineIU=0.9038 | DR=0.8696 | RA=0.4780 | FM=0.6037 | alpha_mean=0.880
# [alpha_0.05_1.00_beta_1.5] Epoch 175 | trainCE=0.09287 | valCE=0.07839 | PixelIoU=0.8335 | LineIU=0.8869 | DR=0.8521 | RA=0.4666 | FM=0.5920 | alpha_mean=0.882
# [alpha_0.05_1.00_beta_1.5] Epoch 176 | trainCE=0.08784 | valCE=0.07765 | PixelIoU=0.8335 | LineIU=0.8895 | DR=0.8617 | RA=0.4708 | FM=0.5961 | alpha_mean=0.879
# [alpha_0.05_1.00_beta_1.5] Epoch 177 | trainCE=0.08818 | valCE=0.07940 | PixelIoU=0.8345 | LineIU=0.9022 | DR=0.8717 | RA=0.4734 | FM=0.6012 | alpha_mean=0.882
# [alpha_0.05_1.00_beta_1.5] Epoch 178 | trainCE=0.08743 | valCE=0.07915 | PixelIoU=0.8323 | LineIU=0.8873 | DR=0.8586 | RA=0.4682 | FM=0.5927 | alpha_mean=0.880
# [alpha_0.05_1.00_beta_1.5] Epoch 179 | trainCE=0.08896 | valCE=0.07837 | PixelIoU=0.8359 | LineIU=0.8812 | DR=0.8545 | RA=0.4628 | FM=0.5886 | alpha_mean=0.883
# [alpha_0.05_1.00_beta_1.5] Epoch 180 | trainCE=0.09095 | valCE=0.07903 | PixelIoU=0.8335 | LineIU=0.8886 | DR=0.8571 | RA=0.4645 | FM=0.5898 | alpha_mean=0.881
# [alpha_0.05_1.00_beta_1.5] Epoch 181 | trainCE=0.09260 | valCE=0.08005 | PixelIoU=0.8312 | LineIU=0.8817 | DR=0.8498 | RA=0.4652 | FM=0.5901 | alpha_mean=0.882
# [alpha_0.05_1.00_beta_1.5] Epoch 182 | trainCE=0.09846 | valCE=0.07984 | PixelIoU=0.8338 | LineIU=0.9009 | DR=0.8713 | RA=0.4476 | FM=0.5794 | alpha_mean=0.881
# [alpha_0.05_1.00_beta_1.5] Epoch 183 | trainCE=0.08405 | valCE=0.07882 | PixelIoU=0.8322 | LineIU=0.8951 | DR=0.8626 | RA=0.4701 | FM=0.5965 | alpha_mean=0.881
# [alpha_0.05_1.00_beta_1.5] Epoch 184 | trainCE=0.08994 | valCE=0.07971 | PixelIoU=0.8345 | LineIU=0.8976 | DR=0.8700 | RA=0.4765 | FM=0.6038 | alpha_mean=0.884
# [alpha_0.05_1.00_beta_1.5] Epoch 185 | trainCE=0.08870 | valCE=0.08099 | PixelIoU=0.8326 | LineIU=0.8910 | DR=0.8559 | RA=0.4408 | FM=0.5695 | alpha_mean=0.880
# [alpha_0.05_1.00_beta_1.5] Epoch 186 | trainCE=0.10032 | valCE=0.07780 | PixelIoU=0.8350 | LineIU=0.8883 | DR=0.8577 | RA=0.4623 | FM=0.5884 | alpha_mean=0.879
# [alpha_0.05_1.00_beta_1.5] Epoch 187 | trainCE=0.09595 | valCE=0.08091 | PixelIoU=0.8329 | LineIU=0.8942 | DR=0.8688 | RA=0.4674 | FM=0.5945 | alpha_mean=0.883
# [alpha_0.05_1.00_beta_1.5] Epoch 188 | trainCE=0.09276 | valCE=0.08060 | PixelIoU=0.8318 | LineIU=0.8917 | DR=0.8593 | RA=0.4627 | FM=0.5869 | alpha_mean=0.883
# [alpha_0.05_1.00_beta_1.5] Epoch 189 | trainCE=0.08929 | valCE=0.07987 | PixelIoU=0.8348 | LineIU=0.8904 | DR=0.8654 | RA=0.4695 | FM=0.5957 | alpha_mean=0.882
# [alpha_0.05_1.00_beta_1.5] Epoch 190 | trainCE=0.08159 | valCE=0.07982 | PixelIoU=0.8340 | LineIU=0.8992 | DR=0.8714 | RA=0.4754 | FM=0.6023 | alpha_mean=0.882
# [alpha_0.05_1.00_beta_1.5] Epoch 191 | trainCE=0.09070 | valCE=0.08155 | PixelIoU=0.8322 | LineIU=0.8839 | DR=0.8612 | RA=0.4660 | FM=0.5920 | alpha_mean=0.883
# [alpha_0.05_1.00_beta_1.5] Epoch 192 | trainCE=0.09025 | valCE=0.08211 | PixelIoU=0.8294 | LineIU=0.8750 | DR=0.8422 | RA=0.4735 | FM=0.5926 | alpha_mean=0.884
# [alpha_0.05_1.00_beta_1.5] Epoch 193 | trainCE=0.08505 | valCE=0.07905 | PixelIoU=0.8351 | LineIU=0.8954 | DR=0.8669 | RA=0.4709 | FM=0.5971 | alpha_mean=0.883
# [alpha_0.05_1.00_beta_1.5] Epoch 194 | trainCE=0.08714 | valCE=0.08120 | PixelIoU=0.8331 | LineIU=0.8988 | DR=0.8645 | RA=0.4593 | FM=0.5866 | alpha_mean=0.881
# [alpha_0.05_1.00_beta_1.5] Epoch 195 | trainCE=0.08972 | valCE=0.08141 | PixelIoU=0.8316 | LineIU=0.8783 | DR=0.8485 | RA=0.4650 | FM=0.5874 | alpha_mean=0.886
# [alpha_0.05_1.00_beta_1.5] Epoch 196 | trainCE=0.08968 | valCE=0.08129 | PixelIoU=0.8324 | LineIU=0.8892 | DR=0.8602 | RA=0.4647 | FM=0.5897 | alpha_mean=0.883
# [alpha_0.05_1.00_beta_1.5] Epoch 197 | trainCE=0.08061 | valCE=0.07956 | PixelIoU=0.8352 | LineIU=0.8917 | DR=0.8652 | RA=0.4691 | FM=0.5960 | alpha_mean=0.884
# [alpha_0.05_1.00_beta_1.5] Epoch 198 | trainCE=0.08124 | valCE=0.08070 | PixelIoU=0.8344 | LineIU=0.8930 | DR=0.8621 | RA=0.4717 | FM=0.5968 | alpha_mean=0.885
# [alpha_0.05_1.00_beta_1.5] Epoch 199 | trainCE=0.08795 | valCE=0.08115 | PixelIoU=0.8348 | LineIU=0.8899 | DR=0.8578 | RA=0.4570 | FM=0.5836 | alpha_mean=0.887
# [alpha_0.05_1.00_beta_1.5] Epoch 200 | trainCE=0.08632 | valCE=0.08129 | PixelIoU=0.8344 | LineIU=0.8927 | DR=0.8626 | RA=0.4598 | FM=0.5865 | alpha_mean=0.887
# [alpha_0.05_1.00_beta_1.5] Epoch 201 | trainCE=0.08424 | valCE=0.08322 | PixelIoU=0.8295 | LineIU=0.8903 | DR=0.8551 | RA=0.4601 | FM=0.5855 | alpha_mean=0.884
# [alpha_0.05_1.00_beta_1.5] Epoch 202 | trainCE=0.09230 | valCE=0.08077 | PixelIoU=0.8344 | LineIU=0.9064 | DR=0.8776 | RA=0.4817 | FM=0.6102 | alpha_mean=0.884
# [alpha_0.05_1.00_beta_1.5] Epoch 203 | trainCE=0.08995 | valCE=0.08147 | PixelIoU=0.8325 | LineIU=0.8890 | DR=0.8588 | RA=0.4544 | FM=0.5807 | alpha_mean=0.884
# [alpha_0.05_1.00_beta_1.5] Epoch 204 | trainCE=0.07978 | valCE=0.08205 | PixelIoU=0.8331 | LineIU=0.8900 | DR=0.8567 | RA=0.4710 | FM=0.5950 | alpha_mean=0.886
# [alpha_0.05_1.00_beta_1.5] Epoch 205 | trainCE=0.09007 | valCE=0.08238 | PixelIoU=0.8322 | LineIU=0.8948 | DR=0.8591 | RA=0.4665 | FM=0.5916 | alpha_mean=0.887
# [alpha_0.05_1.00_beta_1.5] Epoch 206 | trainCE=0.08779 | valCE=0.08134 | PixelIoU=0.8345 | LineIU=0.8947 | DR=0.8685 | RA=0.4798 | FM=0.6043 | alpha_mean=0.885
# [alpha_0.05_1.00_beta_1.5] Epoch 207 | trainCE=0.09504 | valCE=0.08095 | PixelIoU=0.8306 | LineIU=0.8934 | DR=0.8497 | RA=0.4514 | FM=0.5769 | alpha_mean=0.884
# [alpha_0.05_1.00_beta_1.5] Epoch 208 | trainCE=0.09058 | valCE=0.08103 | PixelIoU=0.8344 | LineIU=0.8944 | DR=0.8664 | RA=0.4709 | FM=0.5964 | alpha_mean=0.885
# [alpha_0.05_1.00_beta_1.5] Epoch 209 | trainCE=0.08291 | valCE=0.08244 | PixelIoU=0.8337 | LineIU=0.8862 | DR=0.8592 | RA=0.4656 | FM=0.5904 | alpha_mean=0.890
# [alpha_0.05_1.00_beta_1.5] Epoch 210 | trainCE=0.08970 | valCE=0.08263 | PixelIoU=0.8316 | LineIU=0.8894 | DR=0.8672 | RA=0.4715 | FM=0.5970 | alpha_mean=0.887
# [alpha_0.05_1.00_beta_1.5] Epoch 211 | trainCE=0.08930 | valCE=0.08147 | PixelIoU=0.8332 | LineIU=0.8998 | DR=0.8677 | RA=0.4728 | FM=0.5984 | alpha_mean=0.889
# [alpha_0.05_1.00_beta_1.5] Epoch 212 | trainCE=0.07935 | valCE=0.08148 | PixelIoU=0.8342 | LineIU=0.8820 | DR=0.8559 | RA=0.4652 | FM=0.5886 | alpha_mean=0.887
# [alpha_0.05_1.00_beta_1.5] Epoch 213 | trainCE=0.08735 | valCE=0.08123 | PixelIoU=0.8333 | LineIU=0.9003 | DR=0.8674 | RA=0.4715 | FM=0.5984 | alpha_mean=0.890
# [alpha_0.05_1.00_beta_1.5] Epoch 214 | trainCE=0.08099 | valCE=0.07969 | PixelIoU=0.8354 | LineIU=0.9007 | DR=0.8673 | RA=0.4655 | FM=0.5921 | alpha_mean=0.885
# [alpha_0.05_1.00_beta_1.5] Epoch 215 | trainCE=0.08277 | valCE=0.08172 | PixelIoU=0.8341 | LineIU=0.8948 | DR=0.8651 | RA=0.4670 | FM=0.5934 | alpha_mean=0.888
# [alpha_0.05_1.00_beta_1.5] Epoch 216 | trainCE=0.08137 | valCE=0.08234 | PixelIoU=0.8332 | LineIU=0.8894 | DR=0.8622 | RA=0.4656 | FM=0.5909 | alpha_mean=0.884
# [alpha_0.05_1.00_beta_1.5] Epoch 217 | trainCE=0.07931 | valCE=0.08113 | PixelIoU=0.8334 | LineIU=0.8977 | DR=0.8639 | RA=0.4556 | FM=0.5824 | alpha_mean=0.886
# [alpha_0.05_1.00_beta_1.5] Epoch 218 | trainCE=0.09059 | valCE=0.08258 | PixelIoU=0.8334 | LineIU=0.8864 | DR=0.8568 | RA=0.4691 | FM=0.5925 | alpha_mean=0.889
# [alpha_0.05_1.00_beta_1.5] Epoch 219 | trainCE=0.07995 | valCE=0.08156 | PixelIoU=0.8351 | LineIU=0.8907 | DR=0.8600 | RA=0.4685 | FM=0.5941 | alpha_mean=0.887
# [alpha_0.05_1.00_beta_1.5] Epoch 220 | trainCE=0.07941 | valCE=0.08127 | PixelIoU=0.8356 | LineIU=0.8909 | DR=0.8576 | RA=0.4678 | FM=0.5930 | alpha_mean=0.890
# [alpha_0.05_1.00_beta_1.5] Epoch 221 | trainCE=0.08786 | valCE=0.08307 | PixelIoU=0.8352 | LineIU=0.8961 | DR=0.8683 | RA=0.4641 | FM=0.5918 | alpha_mean=0.888
# [alpha_0.05_1.00_beta_1.5] Epoch 222 | trainCE=0.09068 | valCE=0.08235 | PixelIoU=0.8329 | LineIU=0.8895 | DR=0.8609 | RA=0.4629 | FM=0.5883 | alpha_mean=0.887
# [alpha_0.05_1.00_beta_1.5] Epoch 223 | trainCE=0.08697 | valCE=0.08157 | PixelIoU=0.8348 | LineIU=0.9033 | DR=0.8724 | RA=0.4594 | FM=0.5885 | alpha_mean=0.885
# [alpha_0.05_1.00_beta_1.5] Epoch 224 | trainCE=0.08137 | valCE=0.08286 | PixelIoU=0.8331 | LineIU=0.8990 | DR=0.8700 | RA=0.4725 | FM=0.6001 | alpha_mean=0.888
# [alpha_0.05_1.00_beta_1.5] Epoch 225 | trainCE=0.08933 | valCE=0.08252 | PixelIoU=0.8343 | LineIU=0.8936 | DR=0.8624 | RA=0.4599 | FM=0.5865 | alpha_mean=0.888
# [alpha_0.05_1.00_beta_1.5] Epoch 226 | trainCE=0.08473 | valCE=0.08095 | PixelIoU=0.8354 | LineIU=0.8942 | DR=0.8636 | RA=0.4681 | FM=0.5952 | alpha_mean=0.889
# [alpha_0.05_1.00_beta_1.5] Epoch 227 | trainCE=0.08976 | valCE=0.08291 | PixelIoU=0.8325 | LineIU=0.8947 | DR=0.8604 | RA=0.4685 | FM=0.5938 | alpha_mean=0.889
# [alpha_0.05_1.00_beta_1.5] Epoch 228 | trainCE=0.08288 | valCE=0.08202 | PixelIoU=0.8344 | LineIU=0.8987 | DR=0.8683 | RA=0.4639 | FM=0.5913 | alpha_mean=0.887
# [alpha_0.05_1.00_beta_1.5] Epoch 229 | trainCE=0.07979 | valCE=0.08343 | PixelIoU=0.8307 | LineIU=0.8968 | DR=0.8559 | RA=0.4676 | FM=0.5912 | alpha_mean=0.889
# [alpha_0.05_1.00_beta_1.5] Epoch 230 | trainCE=0.09195 | valCE=0.08179 | PixelIoU=0.8353 | LineIU=0.9014 | DR=0.8691 | RA=0.4621 | FM=0.5899 | alpha_mean=0.888
# [alpha_0.05_1.00_beta_1.5] Epoch 231 | trainCE=0.08816 | valCE=0.08303 | PixelIoU=0.8328 | LineIU=0.8936 | DR=0.8622 | RA=0.4603 | FM=0.5859 | alpha_mean=0.890
# [alpha_0.05_1.00_beta_1.5] Epoch 232 | trainCE=0.08419 | valCE=0.08348 | PixelIoU=0.8327 | LineIU=0.8896 | DR=0.8631 | RA=0.4580 | FM=0.5851 | alpha_mean=0.889
# [alpha_0.05_1.00_beta_1.5] Epoch 233 | trainCE=0.08836 | valCE=0.08267 | PixelIoU=0.8343 | LineIU=0.8921 | DR=0.8610 | RA=0.4591 | FM=0.5859 | alpha_mean=0.890
# [alpha_0.05_1.00_beta_1.5] Epoch 234 | trainCE=0.07745 | valCE=0.08354 | PixelIoU=0.8326 | LineIU=0.8857 | DR=0.8512 | RA=0.4594 | FM=0.5836 | alpha_mean=0.890
# [alpha_0.05_1.00_beta_1.5] Epoch 235 | trainCE=0.08454 | valCE=0.08243 | PixelIoU=0.8346 | LineIU=0.8952 | DR=0.8596 | RA=0.4637 | FM=0.5893 | alpha_mean=0.889
# [alpha_0.05_1.00_beta_1.5] Epoch 236 | trainCE=0.08823 | valCE=0.08280 | PixelIoU=0.8342 | LineIU=0.8930 | DR=0.8600 | RA=0.4652 | FM=0.5909 | alpha_mean=0.889
# [alpha_0.05_1.00_beta_1.5] Epoch 237 | trainCE=0.08443 | valCE=0.08332 | PixelIoU=0.8337 | LineIU=0.8916 | DR=0.8613 | RA=0.4623 | FM=0.5889 | alpha_mean=0.889
# [alpha_0.05_1.00_beta_1.5] Epoch 238 | trainCE=0.08935 | valCE=0.08346 | PixelIoU=0.8332 | LineIU=0.8931 | DR=0.8642 | RA=0.4607 | FM=0.5885 | alpha_mean=0.890
# [alpha_0.05_1.00_beta_1.5] Epoch 239 | trainCE=0.08606 | valCE=0.08222 | PixelIoU=0.8346 | LineIU=0.8892 | DR=0.8608 | RA=0.4663 | FM=0.5922 | alpha_mean=0.888
# [alpha_0.05_1.00_beta_1.5] Epoch 240 | trainCE=0.08359 | valCE=0.08371 | PixelIoU=0.8335 | LineIU=0.8870 | DR=0.8578 | RA=0.4637 | FM=0.5885 | alpha_mean=0.889
# [alpha_0.05_1.00_beta_1.5] Epoch 241 | trainCE=0.08389 | valCE=0.08321 | PixelIoU=0.8345 | LineIU=0.8941 | DR=0.8641 | RA=0.4645 | FM=0.5906 | alpha_mean=0.891
# [alpha_0.05_1.00_beta_1.5] Epoch 242 | trainCE=0.09077 | valCE=0.08320 | PixelIoU=0.8327 | LineIU=0.8875 | DR=0.8541 | RA=0.4627 | FM=0.5868 | alpha_mean=0.890
# [alpha_0.05_1.00_beta_1.5] Epoch 243 | trainCE=0.08671 | valCE=0.08383 | PixelIoU=0.8329 | LineIU=0.8904 | DR=0.8598 | RA=0.4639 | FM=0.5889 | alpha_mean=0.890
# [alpha_0.05_1.00_beta_1.5] Epoch 244 | trainCE=0.08745 | valCE=0.08347 | PixelIoU=0.8342 | LineIU=0.8860 | DR=0.8559 | RA=0.4670 | FM=0.5907 | alpha_mean=0.887
# [alpha_0.05_1.00_beta_1.5] Epoch 245 | trainCE=0.08736 | valCE=0.08248 | PixelIoU=0.8344 | LineIU=0.8907 | DR=0.8617 | RA=0.4628 | FM=0.5890 | alpha_mean=0.890
# [alpha_0.05_1.00_beta_1.5] Epoch 246 | trainCE=0.09091 | valCE=0.08367 | PixelIoU=0.8330 | LineIU=0.8935 | DR=0.8643 | RA=0.4610 | FM=0.5883 | alpha_mean=0.891
# [alpha_0.05_1.00_beta_1.5] Epoch 247 | trainCE=0.08681 | valCE=0.08378 | PixelIoU=0.8346 | LineIU=0.8934 | DR=0.8599 | RA=0.4607 | FM=0.5865 | alpha_mean=0.890
# [alpha_0.05_1.00_beta_1.5] Epoch 248 | trainCE=0.08715 | valCE=0.08239 | PixelIoU=0.8350 | LineIU=0.8878 | DR=0.8559 | RA=0.4618 | FM=0.5867 | alpha_mean=0.890
# [alpha_0.05_1.00_beta_1.5] Epoch 249 | trainCE=0.08526 | valCE=0.08409 | PixelIoU=0.8338 | LineIU=0.8899 | DR=0.8681 | RA=0.4709 | FM=0.5972 | alpha_mean=0.891
# [alpha_0.05_1.00_beta_1.5] Epoch 250 | trainCE=0.08227 | valCE=0.08386 | PixelIoU=0.8349 | LineIU=0.8970 | DR=0.8714 | RA=0.4727 | FM=0.5992 | alpha_mean=0.891
#
# --- Evaluating best model on TEST split for alpha_0.05_1.00_beta_1.5 ---
# TEST RESULTS | PixelIoU=0.8621 | LineIU=0.9510 | DR=0.9270 | RA=0.4676 | FM=0.6184
#
# ==========================================================================================
# Run: alpha_0.05_1.00_beta_1.5
# Device: cuda
# alpha_min=1, alpha_max=1.5, beta_gate=1.5
# ==========================================================================================
# Loaded Stage 1 model from G:\Best UDIDS\best_maskprob_gauss.pt
# [dataset] 3 pairs loaded from G:\historical document analysis\Latin2\images\train
# [dataset] 10 pairs loaded from G:\historical document analysis\Latin2\images\val
# [dataset] 15 pairs loaded from G:\historical document analysis\Latin2\images\test
# [alpha_0.05_1.00_beta_1.5] Epoch 001 | trainCE=0.36899 | valCE=0.35333 | PixelIoU=0.5495 | LineIU=0.1497 | DR=0.0017 | RA=0.0021 | FM=0.0019 | alpha_mean=1.248
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.1497
# [alpha_0.05_1.00_beta_1.5] Epoch 002 | trainCE=0.29929 | valCE=0.33433 | PixelIoU=0.5500 | LineIU=0.1518 | DR=0.0017 | RA=0.0021 | FM=0.0019 | alpha_mean=1.247
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.1518
# [alpha_0.05_1.00_beta_1.5] Epoch 003 | trainCE=0.32543 | valCE=0.31076 | PixelIoU=0.5532 | LineIU=0.1692 | DR=0.0017 | RA=0.0021 | FM=0.0019 | alpha_mean=1.244
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.1692
# [alpha_0.05_1.00_beta_1.5] Epoch 004 | trainCE=0.34085 | valCE=0.28442 | PixelIoU=0.5739 | LineIU=0.3485 | DR=0.0092 | RA=0.0097 | FM=0.0094 | alpha_mean=1.240
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.3485
# [alpha_0.05_1.00_beta_1.5] Epoch 005 | trainCE=0.30860 | valCE=0.26624 | PixelIoU=0.5747 | LineIU=0.3428 | DR=0.0116 | RA=0.0109 | FM=0.0112 | alpha_mean=1.239
# [alpha_0.05_1.00_beta_1.5] Epoch 006 | trainCE=0.24277 | valCE=0.25303 | PixelIoU=0.6079 | LineIU=0.6298 | DR=0.0908 | RA=0.0857 | FM=0.0878 | alpha_mean=1.237
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.6298
# [alpha_0.05_1.00_beta_1.5] Epoch 007 | trainCE=0.28294 | valCE=0.24357 | PixelIoU=0.6191 | LineIU=0.7001 | DR=0.1220 | RA=0.1104 | FM=0.1158 | alpha_mean=1.235
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7001
# [alpha_0.05_1.00_beta_1.5] Epoch 008 | trainCE=0.26513 | valCE=0.23340 | PixelIoU=0.6291 | LineIU=0.7256 | DR=0.1801 | RA=0.1568 | FM=0.1670 | alpha_mean=1.234
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7256
# [alpha_0.05_1.00_beta_1.5] Epoch 009 | trainCE=0.27144 | valCE=0.22842 | PixelIoU=0.6297 | LineIU=0.7138 | DR=0.1739 | RA=0.1422 | FM=0.1554 | alpha_mean=1.235
# [alpha_0.05_1.00_beta_1.5] Epoch 010 | trainCE=0.24089 | valCE=0.22064 | PixelIoU=0.6425 | LineIU=0.7673 | DR=0.2450 | RA=0.1970 | FM=0.2164 | alpha_mean=1.232
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7673
# [alpha_0.05_1.00_beta_1.5] Epoch 011 | trainCE=0.26916 | valCE=0.21659 | PixelIoU=0.6477 | LineIU=0.7677 | DR=0.2942 | RA=0.2316 | FM=0.2561 | alpha_mean=1.230
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7677
# [alpha_0.05_1.00_beta_1.5] Epoch 012 | trainCE=0.20887 | valCE=0.21491 | PixelIoU=0.6551 | LineIU=0.7730 | DR=0.3394 | RA=0.2657 | FM=0.2944 | alpha_mean=1.228
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7730
# [alpha_0.05_1.00_beta_1.5] Epoch 013 | trainCE=0.25591 | valCE=0.20826 | PixelIoU=0.6615 | LineIU=0.7771 | DR=0.4054 | RA=0.3016 | FM=0.3400 | alpha_mean=1.228
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7771
# [alpha_0.05_1.00_beta_1.5] Epoch 014 | trainCE=0.22299 | valCE=0.20544 | PixelIoU=0.6622 | LineIU=0.7745 | DR=0.4005 | RA=0.2904 | FM=0.3318 | alpha_mean=1.228
# [alpha_0.05_1.00_beta_1.5] Epoch 015 | trainCE=0.28502 | valCE=0.20018 | PixelIoU=0.6715 | LineIU=0.7780 | DR=0.4397 | RA=0.3085 | FM=0.3560 | alpha_mean=1.226
# Saved best checkpoint: alpha_sensitivity_output\alpha_0.05_1.00_beta_1.5\best_lineiu.pt | LineIU=0.7780
# ...
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 175 | trainCE=0.52300 | valCE=0.60753 | PixelIoU=0.6165 | LineIU=0.5684 | DR=0.1192 | RA=0.1200 | FM=0.1190 | alpha_mean=3.678
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 176 | trainCE=0.60053 | valCE=0.60764 | PixelIoU=0.6167 | LineIU=0.5701 | DR=0.1210 | RA=0.1237 | FM=0.1218 | alpha_mean=3.678
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 177 | trainCE=0.49854 | valCE=0.60845 | PixelIoU=0.6161 | LineIU=0.5632 | DR=0.1154 | RA=0.1173 | FM=0.1158 | alpha_mean=3.678
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 178 | trainCE=0.52739 | valCE=0.60699 | PixelIoU=0.6167 | LineIU=0.5701 | DR=0.1201 | RA=0.1210 | FM=0.1200 | alpha_mean=3.678
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 179 | trainCE=0.48874 | valCE=0.60766 | PixelIoU=0.6167 | LineIU=0.5689 | DR=0.1220 | RA=0.1233 | FM=0.1221 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 180 | trainCE=0.49064 | valCE=0.60774 | PixelIoU=0.6167 | LineIU=0.5692 | DR=0.1210 | RA=0.1230 | FM=0.1214 | alpha_mean=3.678
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 181 | trainCE=0.55945 | valCE=0.60964 | PixelIoU=0.6163 | LineIU=0.5664 | DR=0.1181 | RA=0.1193 | FM=0.1182 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 182 | trainCE=0.54345 | valCE=0.60951 | PixelIoU=0.6161 | LineIU=0.5620 | DR=0.1146 | RA=0.1163 | FM=0.1150 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 183 | trainCE=0.58780 | valCE=0.60678 | PixelIoU=0.6168 | LineIU=0.5726 | DR=0.1210 | RA=0.1223 | FM=0.1211 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 184 | trainCE=0.58945 | valCE=0.61068 | PixelIoU=0.6162 | LineIU=0.5650 | DR=0.1146 | RA=0.1160 | FM=0.1148 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 185 | trainCE=0.53347 | valCE=0.60853 | PixelIoU=0.6165 | LineIU=0.5659 | DR=0.1164 | RA=0.1178 | FM=0.1166 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 186 | trainCE=0.47075 | valCE=0.60898 | PixelIoU=0.6165 | LineIU=0.5659 | DR=0.1201 | RA=0.1223 | FM=0.1206 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 187 | trainCE=0.50338 | valCE=0.61053 | PixelIoU=0.6163 | LineIU=0.5640 | DR=0.1192 | RA=0.1206 | FM=0.1193 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 188 | trainCE=0.57085 | valCE=0.61055 | PixelIoU=0.6162 | LineIU=0.5638 | DR=0.1172 | RA=0.1184 | FM=0.1173 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 189 | trainCE=0.45745 | valCE=0.60868 | PixelIoU=0.6164 | LineIU=0.5646 | DR=0.1172 | RA=0.1175 | FM=0.1168 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 190 | trainCE=0.73355 | valCE=0.60894 | PixelIoU=0.6164 | LineIU=0.5671 | DR=0.1192 | RA=0.1206 | FM=0.1194 | alpha_mean=3.678
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 191 | trainCE=0.72262 | valCE=0.60947 | PixelIoU=0.6167 | LineIU=0.5696 | DR=0.1207 | RA=0.1238 | FM=0.1217 | alpha_mean=3.678
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 192 | trainCE=0.50119 | valCE=0.61094 | PixelIoU=0.6161 | LineIU=0.5629 | DR=0.1163 | RA=0.1186 | FM=0.1170 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 193 | trainCE=0.58785 | valCE=0.60989 | PixelIoU=0.6162 | LineIU=0.5639 | DR=0.1180 | RA=0.1210 | FM=0.1190 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 194 | trainCE=0.51250 | valCE=0.61009 | PixelIoU=0.6166 | LineIU=0.5664 | DR=0.1198 | RA=0.1232 | FM=0.1210 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 195 | trainCE=0.46371 | valCE=0.60990 | PixelIoU=0.6163 | LineIU=0.5656 | DR=0.1171 | RA=0.1190 | FM=0.1175 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 196 | trainCE=0.56475 | valCE=0.60951 | PixelIoU=0.6164 | LineIU=0.5638 | DR=0.1189 | RA=0.1211 | FM=0.1195 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 197 | trainCE=0.61502 | valCE=0.60818 | PixelIoU=0.6166 | LineIU=0.5715 | DR=0.1219 | RA=0.1237 | FM=0.1222 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 198 | trainCE=0.45107 | valCE=0.60798 | PixelIoU=0.6169 | LineIU=0.5733 | DR=0.1218 | RA=0.1245 | FM=0.1226 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 199 | trainCE=0.48614 | valCE=0.60916 | PixelIoU=0.6167 | LineIU=0.5716 | DR=0.1207 | RA=0.1232 | FM=0.1214 | alpha_mean=3.677
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 200 | trainCE=0.45953 | valCE=0.61014 | PixelIoU=0.6166 | LineIU=0.5664 | DR=0.1198 | RA=0.1212 | FM=0.1200 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 201 | trainCE=0.66193 | valCE=0.61008 | PixelIoU=0.6165 | LineIU=0.5638 | DR=0.1189 | RA=0.1211 | FM=0.1195 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 202 | trainCE=0.51832 | valCE=0.61026 | PixelIoU=0.6164 | LineIU=0.5664 | DR=0.1189 | RA=0.1211 | FM=0.1195 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 203 | trainCE=0.59473 | valCE=0.60932 | PixelIoU=0.6166 | LineIU=0.5712 | DR=0.1198 | RA=0.1227 | FM=0.1208 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 204 | trainCE=0.53464 | valCE=0.61113 | PixelIoU=0.6163 | LineIU=0.5656 | DR=0.1189 | RA=0.1210 | FM=0.1195 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 205 | trainCE=0.64882 | valCE=0.61075 | PixelIoU=0.6165 | LineIU=0.5669 | DR=0.1180 | RA=0.1199 | FM=0.1184 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 206 | trainCE=0.62283 | valCE=0.60827 | PixelIoU=0.6164 | LineIU=0.5672 | DR=0.1180 | RA=0.1203 | FM=0.1187 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 207 | trainCE=0.60472 | valCE=0.61022 | PixelIoU=0.6164 | LineIU=0.5677 | DR=0.1181 | RA=0.1195 | FM=0.1183 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 208 | trainCE=0.61120 | valCE=0.60892 | PixelIoU=0.6169 | LineIU=0.5720 | DR=0.1201 | RA=0.1217 | FM=0.1203 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 209 | trainCE=0.38251 | valCE=0.60948 | PixelIoU=0.6164 | LineIU=0.5720 | DR=0.1155 | RA=0.1170 | FM=0.1158 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 210 | trainCE=0.49351 | valCE=0.60986 | PixelIoU=0.6168 | LineIU=0.5712 | DR=0.1207 | RA=0.1237 | FM=0.1217 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 211 | trainCE=0.55849 | valCE=0.60959 | PixelIoU=0.6167 | LineIU=0.5712 | DR=0.1189 | RA=0.1218 | FM=0.1199 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 212 | trainCE=0.45931 | valCE=0.60795 | PixelIoU=0.6169 | LineIU=0.5693 | DR=0.1219 | RA=0.1245 | FM=0.1226 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 213 | trainCE=0.56407 | valCE=0.60950 | PixelIoU=0.6167 | LineIU=0.5698 | DR=0.1198 | RA=0.1225 | FM=0.1207 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 214 | trainCE=0.48575 | valCE=0.60759 | PixelIoU=0.6170 | LineIU=0.5710 | DR=0.1219 | RA=0.1239 | FM=0.1224 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 215 | trainCE=0.46768 | valCE=0.60992 | PixelIoU=0.6165 | LineIU=0.5646 | DR=0.1198 | RA=0.1226 | FM=0.1207 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 216 | trainCE=0.52724 | valCE=0.60850 | PixelIoU=0.6168 | LineIU=0.5729 | DR=0.1216 | RA=0.1239 | FM=0.1222 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 217 | trainCE=0.48168 | valCE=0.61023 | PixelIoU=0.6166 | LineIU=0.5664 | DR=0.1198 | RA=0.1221 | FM=0.1204 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 218 | trainCE=0.46392 | valCE=0.60811 | PixelIoU=0.6169 | LineIU=0.5718 | DR=0.1198 | RA=0.1211 | FM=0.1199 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 219 | trainCE=0.52879 | valCE=0.61038 | PixelIoU=0.6166 | LineIU=0.5663 | DR=0.1198 | RA=0.1218 | FM=0.1203 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 220 | trainCE=0.49711 | valCE=0.60928 | PixelIoU=0.6170 | LineIU=0.5730 | DR=0.1207 | RA=0.1227 | FM=0.1212 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 221 | trainCE=0.50733 | valCE=0.61029 | PixelIoU=0.6167 | LineIU=0.5672 | DR=0.1198 | RA=0.1224 | FM=0.1205 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 222 | trainCE=0.57252 | valCE=0.60991 | PixelIoU=0.6168 | LineIU=0.5717 | DR=0.1189 | RA=0.1209 | FM=0.1193 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 223 | trainCE=0.48716 | valCE=0.61082 | PixelIoU=0.6166 | LineIU=0.5640 | DR=0.1198 | RA=0.1220 | FM=0.1204 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 224 | trainCE=0.55877 | valCE=0.61079 | PixelIoU=0.6166 | LineIU=0.5667 | DR=0.1198 | RA=0.1218 | FM=0.1203 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 225 | trainCE=0.53956 | valCE=0.61061 | PixelIoU=0.6167 | LineIU=0.5692 | DR=0.1198 | RA=0.1224 | FM=0.1206 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 226 | trainCE=0.63377 | valCE=0.61033 | PixelIoU=0.6166 | LineIU=0.5692 | DR=0.1198 | RA=0.1219 | FM=0.1204 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 227 | trainCE=0.54512 | valCE=0.60999 | PixelIoU=0.6166 | LineIU=0.5649 | DR=0.1198 | RA=0.1221 | FM=0.1205 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 228 | trainCE=0.51320 | valCE=0.60963 | PixelIoU=0.6170 | LineIU=0.5728 | DR=0.1206 | RA=0.1224 | FM=0.1210 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 229 | trainCE=0.65463 | valCE=0.61174 | PixelIoU=0.6163 | LineIU=0.5646 | DR=0.1180 | RA=0.1194 | FM=0.1182 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 230 | trainCE=0.60166 | valCE=0.60867 | PixelIoU=0.6171 | LineIU=0.5780 | DR=0.1237 | RA=0.1246 | FM=0.1236 | alpha_mean=3.676
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 231 | trainCE=0.53297 | valCE=0.61024 | PixelIoU=0.6166 | LineIU=0.5700 | DR=0.1207 | RA=0.1230 | FM=0.1213 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 232 | trainCE=0.39998 | valCE=0.60991 | PixelIoU=0.6168 | LineIU=0.5708 | DR=0.1198 | RA=0.1221 | FM=0.1204 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 233 | trainCE=0.57103 | valCE=0.60970 | PixelIoU=0.6169 | LineIU=0.5738 | DR=0.1219 | RA=0.1238 | FM=0.1223 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 234 | trainCE=0.48653 | valCE=0.61078 | PixelIoU=0.6166 | LineIU=0.5674 | DR=0.1198 | RA=0.1225 | FM=0.1206 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 235 | trainCE=0.58045 | valCE=0.61071 | PixelIoU=0.6168 | LineIU=0.5701 | DR=0.1207 | RA=0.1228 | FM=0.1212 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 236 | trainCE=0.57568 | valCE=0.60995 | PixelIoU=0.6168 | LineIU=0.5708 | DR=0.1225 | RA=0.1242 | FM=0.1228 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 237 | trainCE=0.53514 | valCE=0.61081 | PixelIoU=0.6166 | LineIU=0.5702 | DR=0.1198 | RA=0.1214 | FM=0.1201 | alpha_mean=3.674
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 238 | trainCE=0.53878 | valCE=0.61118 | PixelIoU=0.6165 | LineIU=0.5689 | DR=0.1198 | RA=0.1218 | FM=0.1203 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 239 | trainCE=0.61188 | valCE=0.60965 | PixelIoU=0.6169 | LineIU=0.5725 | DR=0.1216 | RA=0.1243 | FM=0.1224 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 240 | trainCE=0.52634 | valCE=0.60924 | PixelIoU=0.6169 | LineIU=0.5742 | DR=0.1219 | RA=0.1245 | FM=0.1227 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 241 | trainCE=0.47414 | valCE=0.61096 | PixelIoU=0.6168 | LineIU=0.5730 | DR=0.1225 | RA=0.1243 | FM=0.1229 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 242 | trainCE=0.44216 | valCE=0.61147 | PixelIoU=0.6162 | LineIU=0.5638 | DR=0.1171 | RA=0.1187 | FM=0.1173 | alpha_mean=3.674
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 243 | trainCE=0.53492 | valCE=0.61036 | PixelIoU=0.6168 | LineIU=0.5712 | DR=0.1189 | RA=0.1209 | FM=0.1194 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 244 | trainCE=0.56352 | valCE=0.60993 | PixelIoU=0.6168 | LineIU=0.5712 | DR=0.1225 | RA=0.1247 | FM=0.1231 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 245 | trainCE=0.61148 | valCE=0.61169 | PixelIoU=0.6165 | LineIU=0.5663 | DR=0.1216 | RA=0.1238 | FM=0.1222 | alpha_mean=3.674
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 246 | trainCE=0.49133 | valCE=0.61116 | PixelIoU=0.6166 | LineIU=0.5681 | DR=0.1216 | RA=0.1235 | FM=0.1220 | alpha_mean=3.674
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 247 | trainCE=0.55464 | valCE=0.60930 | PixelIoU=0.6170 | LineIU=0.5737 | DR=0.1228 | RA=0.1242 | FM=0.1229 | alpha_mean=3.674
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 248 | trainCE=0.47277 | valCE=0.61101 | PixelIoU=0.6165 | LineIU=0.5664 | DR=0.1198 | RA=0.1220 | FM=0.1204 | alpha_mean=3.674
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 249 | trainCE=0.52834 | valCE=0.61071 | PixelIoU=0.6168 | LineIU=0.5737 | DR=0.1198 | RA=0.1216 | FM=0.1201 | alpha_mean=3.675
# [alpha_0.05_5.00_beta_1.5_wide] Epoch 250 | trainCE=0.48440 | valCE=0.60920 | PixelIoU=0.6168 | LineIU=0.5701 | DR=0.1201 | RA=0.1216 | FM=0.1203 | alpha_mean=3.674
#
# --- Evaluating best model on TEST split for alpha_0.05_5.00_beta_1.5_wide ---
# TEST RESULTS | PixelIoU=0.6467 | LineIU=0.7226 | DR=0.2053 | RA=0.1952 | FM=0.1992
#
# Alpha sensitivity summary saved to:
# alpha_sensitivity_output\alpha_sensitivity_summary.csv
#
# Summary:
# {'run_name': 'alpha_0.05_1.00_beta_1.5', 'alpha_min': 0.05, 'alpha_max': 1.0, 'beta_gate': 1.5, 'best_epoch': 99, 'best_val_pixel_iou': 0.8298227514126723, 'best_val_lineiu': 0.9304369697551771, 'best_val_dr': 0.8891593883251119, 'best_val_ra': 0.41987463518900664, 'best_val_fm': 0.5598740693707115, 'best_alpha_mean': 0.8460333347320557, 'test_pixel_iou': 0.8620626522787064, 'test_lineiu': 0.9510302914744364, 'test_dr': 0.9270315677050456, 'test_ra': 0.4675652001610781, 'test_fm': 0.6184365295266299}
# {'run_name': 'alpha_0.05_1.00_beta_1.5', 'alpha_min': 1, 'alpha_max': 1.5, 'beta_gate': 1.5, 'best_epoch': 161, 'best_val_pixel_iou': 0.7503772962539854, 'best_val_lineiu': 0.8474078808289208, 'best_val_dr': 0.7397485314490002, 'best_val_ra': 0.4505194321876413, 'best_val_fm': 0.5485058886232146, 'best_alpha_mean': 1.2454865097999572, 'test_pixel_iou': 0.7717084132611677, 'test_lineiu': 0.9000374330077981, 'test_dr': 0.8267620680973585, 'test_ra': 0.5275023805174015, 'test_fm': 0.6423039811081286}
# {'run_name': 'alpha_0.15_1.50_beta_1.5_default', 'alpha_min': 1.5, 'alpha_max': 2.5, 'beta_gate': 1.5, 'best_epoch': 148, 'best_val_pixel_iou': 0.6979422131365858, 'best_val_lineiu': 0.788551841332915, 'best_val_dr': 0.6053615694006997, 'best_val_ra': 0.43386111310354714, 'best_val_fm': 0.4961495674183062, 'best_alpha_mean': 1.8779468655586242, 'test_pixel_iou': 0.7254224009920132, 'test_lineiu': 0.8644590584133592, 'test_dr': 0.7403595544327117, 'test_ra': 0.529816861155041, 'test_fm': 0.6156523543576822}
# {'run_name': 'alpha_0.05_5.00_beta_1.5_wide', 'alpha_min': 2.5, 'alpha_max': 3, 'beta_gate': 1.5, 'best_epoch': 134, 'best_val_pixel_iou': 0.6444091958065608, 'best_val_lineiu': 0.6846649973049834, 'best_val_dr': 0.2860323860754582, 'best_val_ra': 0.2590555486850826, 'best_val_fm': 0.2693410697426095, 'best_alpha_mean': 2.677725839614868, 'test_pixel_iou': 0.6758282846653738, 'test_lineiu': 0.7942577308726542, 'test_dr': 0.4533185266269856, 'test_ra': 0.39684611059662794, 'test_fm': 0.42130645089349944}
# {'run_name': 'alpha_0.05_5.00_beta_1.5_wide', 'alpha_min': 3, 'alpha_max': 3.5, 'beta_gate': 1.5, 'best_epoch': 93, 'best_val_pixel_iou': 0.6275058992338998, 'best_val_lineiu': 0.632734483132303, 'best_val_dr': 0.1778792519695918, 'best_val_ra': 0.1755416830842643, 'best_val_fm': 0.17531642493303376, 'best_alpha_mean': 3.1881697177886963, 'test_pixel_iou': 0.6580986557736175, 'test_lineiu': 0.7634655056278904, 'test_dr': 0.2985700270172092, 'test_ra': 0.2754564121340007, 'test_fm': 0.28524356603867507}
# {'run_name': 'alpha_0.05_5.00_beta_1.5_wide', 'alpha_min': 3.5, 'alpha_max': 4, 'beta_gate': 1.5, 'best_epoch': 96, 'best_val_pixel_iou': 0.6161981065496324, 'best_val_lineiu': 0.5800895656395177, 'best_val_dr': 0.12364180136068444, 'best_val_ra': 0.12574718360714196, 'best_val_fm': 0.12411871459030785, 'best_alpha_mean': 3.6878275156021116, 'test_pixel_iou': 0.6466515066503769, 'test_lineiu': 0.7226051556009977, 'test_dr': 0.20525361617701074, 'test_ra': 0.19519660045449147, 'test_fm': 0.19916291831323318}
